# %% [markdown]
# <a href="https://colab.research.google.com/github/kmilo65/pytorch-opencv/blob/main/Assignment_CNN_CIFAR10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font style="color:blue">Assignment: Implement a CNN for Image Classification on CIFAR10 dataset</font>
#
# We have seen how to implement a CNN (LeNet5 and LeNet with the batch norm) in the last section. We used MNIST and Fashion MNIST dataset which are grayscale or single channel datasets. In this assignment, you will implement a CNN Model ( similar to LeNet ) for classifying objects in the `CIFAR10` dataset.
#
# The CIFAR10 dataset has the following properties
# 1. It has `10` classes.
# 1. It has colored images, so it has `3-channels`.
# 1. The image shape is `32 x 32`.
#
# Samples of CIFAR10- dataset ([source](https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html?highlight=cifar)):
#
# <img src="https://www.learnopencv.com/wp-content/uploads/2020/01/c3_w3_cirar10.png" width=700>
#
#
# # <font color='blue'>Marking Scheme</font>
#
# ### <font style="color:green">Maximum Points: 30
#
# <div>
#     <table>
#         <tr><td><h3>Sr. no.</h3></td> <td><h3>Problem</h3></td> <td><h3>Points</h3></td> </tr>
#         <tr><td><h3>1</h3></td> <td><h3>Implement the CNN Model</h3></td> <td><h3>10</h3></td> </tr>
#         <tr><td><h3>2</h3></td> <td><h3>Find Mean and Std of Training Data</h3></td> <td><h3>5</h3></td> </tr>
#         <tr><td><h3>3</h3></td> <td><h3>Model Training & Accuracy</h3></td> <td><h3>15</h3></td> </tr>
#     </table>
# </div>
#
#
# # <font color='blue'>Problem Description</font>
#
# ### <font color='blue'>1. Implement the CNN Model</font>
# Since the task is to classify objects in a dataset of color images, you need to implement a CNN with 10 output classes. **Also, your model must use `Conv2d`, `BatchNorm2d`, and `ReLU`.**
#
# **You need to define the model architecture in the function: `MyModel` ( Step 1 )**
#
# Hint: For color images you need to use an input shape that is different than the ones we have been using till now, so that it accepts 3 channel inputs.
#
# ### <font color='blue'>2. Find Mean and Std of Training Data</font>
#
# It is a good practice to normalize the training data. To normalize the data, we need to compute mean and std. As the dataset has colored images, it has `3-channel` (RGB or BGR). We have to find mean and std per channel using training data.
#
# **You need to compute the mean and std for the dataset in the function: `get_mean_std_train_data` ( Step 3 )**
#
# ### <font color='blue'>3. Model Training and Accuracy</font>
#
# Once you have defined the model, you can train it. To get better accuracy, you need to play around the training configuration **( Step 5 )** and even the model architecture. You can check the accuracy by running the training loop in `Step 11`.
#
# Here are a few hints on how you can improve the accuracy:
# - Train for longer duration
# - Try with different learning rate
# - Try to add more convolutional layers to the architecture
# - Try to add more nodes in the layers.
#
# You need to achieve **75% accuracy** ( See Step11 ) in order to get full marks for this part.
#
# **You do not need to implement anything for this, just changing the parameters as mentioned above and running the Notebook will give you the accuracy. ( Step 5 and Step 11 )**

# %% [markdown]
# Note that this notebook requires you to change a few stuff in the model to get the desired accuracy. Therefore you need train the model all over again (which seems to be time-consuming).
#
# You can choose to execute this notebook in Google-Colab so that you have access to a GPU-machine and prototype faster.
#
# Once the desired results are acheived, you can copy-paste the changes made in the Colab-notebook to this notebook so that the grading occurs on the latest code.
#
# You can access the Colab-notebook from [here](https://colab.research.google.com/drive/18lgSRmHPagJkB0xmDq5ZiWGkuWcHnUc2?usp=sharing)

# %%
required_training = True

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt  # one of the best graphics library for python

# %%
import os
import time

from typing import Iterable
from dataclasses import dataclass

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torchvision import datasets, transforms
import torchvision

# %% [markdown]
# # <font style="color:blue">1. CNN Model Architecture [10 Points]</font>
#
# You have to write the model code here. You can take reference from LeNet code.
#
# If you do not get higher accuracy, here are a few hints:
# - Try to add more convolutional layers to the architecture
# - Try to add more nodes in the layers.

# %%
class MyModel(nn.Module):
    def __init__(self):
        super(MyModel, self).__init__()

        self.conv_layers = nn.Sequential(
            # Input: (3, 32, 32)
            nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, stride=1, padding=1),  # (64, 32, 32)
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1),  # (64, 32, 32)
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),  # (64, 16, 16)

            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1),  # (128, 16, 16)
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1),  # (128, 16, 16)
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),  # (128, 8, 8)

            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1),  # (256, 8, 8)
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1),  # (256, 8, 8)
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)  # (256, 4, 4)
        )

        self.fc_layers = nn.Sequential(
            nn.Linear(256 * 4 * 4, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(512, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(256, 10)  # Output layer (10 classes)
        )

    def forward(self, x):
        x = self.conv_layers(x)
        x = torch.flatten(x, 1)  # Flatten before FC layers
        x = self.fc_layers(x)
        return x

# %% [markdown]
# # <font style="color:blue">2. Display the Network</font>

# %%
my_model = MyModel()
print(my_model)
# Out:
# MyModel(
#   (conv_layers): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc_layers): Sequential(
#     (0): Linear(in_features=4096, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=512, out_features=256, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=256, out_features=10, bias=True)
#   )
# )

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# # <font style="color:blue">3. Find Mean and STD of CIFAR10 Data [5 Points]</font>
#
# Function **`get_mean_std_train_data`** should `return` `mean` and `std` of training data. You can refer to the code used in the previous section for finding the mean and std of the training data.

# %%
def get_mean_std_train_data(data_root):

    train_transform = transforms.Compose([transforms.ToTensor()])
    train_set = datasets.CIFAR10(root=data_root, train=True, download=False, transform=train_transform)

    # return mean (numpy.ndarray) and std (numpy.ndarray)
    # Stack all images into a single tensor
    data = torch.stack([img for img, _ in train_set])  # Shape: (N, C, H, W)

    # Compute mean and std along (0, 2, 3) to exclude batch and spatial dimensions
    mean = data.mean(dim=(0, 2, 3)).numpy()
    std = data.std(dim=(0, 2, 3)).numpy()

    return mean, std

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %%
def get_data(batch_size, data_root, num_workers=1):


    try:
        mean, std = get_mean_std_train_data(data_root)
        assert len(mean) == len(std) == 3
    except:
        mean = np.array([0.5, 0.5, 0.5])
        std = np.array([0.5, 0.5, 0.5])


    train_test_transforms = transforms.Compose([
        # this re-scale image tensor values between 0-1. image_tensor /= 255
        transforms.ToTensor(),
        # subtract mean and divide by variance.
        transforms.Normalize(mean, std)
    ])

    # train dataloader
    train_loader = torch.utils.data.DataLoader(
        datasets.CIFAR10(root=data_root, train=True, download=False, transform=train_test_transforms),
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers
    )

    # test dataloader
    test_loader = torch.utils.data.DataLoader(
        datasets.CIFAR10(root=data_root, train=False, download=False, transform=train_test_transforms),
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers
    )
    return train_loader, test_loader

# %%
def get_data(batch_size, data_root, num_workers=1):


    try:
        mean, std = get_mean_std_train_data(data_root)
        assert len(mean) == len(std) == 3
    except:
        mean = np.array([0.5, 0.5, 0.5])
        std = np.array([0.5, 0.5, 0.5])


    train_test_transforms = transforms.Compose([
        # this re-scale image tensor values between 0-1. image_tensor /= 255
        transforms.ToTensor(),
        # subtract mean and divide by variance.
        transforms.Normalize(mean, std)
    ])

    # train dataloader
    train_loader = torch.utils.data.DataLoader(
        datasets.CIFAR10(root=data_root, train=True, download=True, transform=train_test_transforms),
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers
    )

    # test dataloader
    test_loader = torch.utils.data.DataLoader(
        datasets.CIFAR10(root=data_root, train=False, download=True, transform=train_test_transforms),
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers
    )
    return train_loader, test_loader

# %% [markdown]
# # <font style="color:blue">4. System Configuration</font>

# %%
@dataclass
class SystemConfiguration:
    '''
    Describes the common system setting needed for reproducible training
    '''
    seed: int = 42  # seed number to set the state of all random number generators
    cudnn_benchmark_enabled: bool = True  # enable CuDNN benchmark for the sake of performance
    cudnn_deterministic: bool = True  # make cudnn deterministic (reproducible training)

# %% [markdown]
# # <font style="color:blue">5. Training Configuration [15 Points]</font>
# All training parameters are defined here. So,
# This is where you can improve your accuracy, apart from improving the architecture.
#
# Here are a few hints on how you can improve the accuracy:
# - Train for longer duration
# - Try with different learning rate
#
# **You need to achieve 75% accuracy in order to get full marks for this part.**
#
# **You will see the effect of these changes when you run Step 11**

# %%
@dataclass
class TrainingConfiguration:
    '''
    Describes configuration of the training process
    '''
    batch_size: int = 128  # amount of data to pass through the network at each forward-backward iteration
    epochs_count: int = 450  # number of times the whole dataset will be passed through the network
    learning_rate: float = 0.00009  # determines the speed of network's weights update

    log_interval: int = 100  # how many batches to wait between logging training status
    test_interval: int = 1  # how many epochs to wait before another test. Set to 1 to get val loss at each epoch
    data_root: str = "../data"  # folder to save data
    num_workers: int = 10  # number of concurrent processes using to prepare data
    device: str = 'cuda'  # device to use for training.
    # update changed parameters in blow coding block.
    # Please do not change "data_root"

    ###
    ### YOUR CODE HERE
    ###

# %% [markdown]
# # <font style="color:blue">6. System Setup</font>

# %%
def setup_system(system_config: SystemConfiguration) -> None:
    torch.manual_seed(system_config.seed)
    if torch.cuda.is_available():
        torch.backends.cudnn_benchmark_enabled = system_config.cudnn_benchmark_enabled
        torch.backends.cudnn.deterministic = system_config.cudnn_deterministic

# %% [markdown]
# # <font style="color:blue">7. Training</font>
# We are familiar with the training pipeline used in PyTorch. The following steps are performed in the code below:
#
# 1. Send the data to the required device ( CPU/GPU )
# 1. Make a forward pass using the forward method.
# 1. Find the loss using the Cross_Entropy function.
# 1. Find the gradients using the backward function.
# 1. Update the weights using the optimizer.
# 1. Find the accuracy of the model
#
# Repeat the above for the specified number of epochs.

# %%
def train(
    train_config: TrainingConfiguration, model: nn.Module, optimizer: torch.optim.Optimizer,
    train_loader: torch.utils.data.DataLoader, epoch_idx: int
) -> None:

    # change model in training mood
    model.train()

    # to get batch loss
    batch_loss = np.array([])

    # to get batch accuracy
    batch_acc = np.array([])

    for batch_idx, (data, target) in enumerate(train_loader):

        # clone target
        indx_target = target.clone()
        # send data to device (its is medatory if GPU has to be used)
        data = data.to(train_config.device)
        # send target to device
        target = target.to(train_config.device)

        # reset parameters gradient to zero
        optimizer.zero_grad()

        # forward pass to the model
        output = model(data)

        # cross entropy loss
        loss = F.cross_entropy(output, target)

        # find gradients w.r.t training parameters
        loss.backward()
        # Update parameters using gardients
        optimizer.step()

        batch_loss = np.append(batch_loss, [loss.item()])

        # Score to probability using softmax
        prob = F.softmax(output, dim=1)

        # get the index of the max probability
        pred = prob.data.max(dim=1)[1]

        # correct prediction
        correct = pred.cpu().eq(indx_target).sum()

        # accuracy
        acc = float(correct) / float(len(data))

        batch_acc = np.append(batch_acc, [acc])

        if batch_idx % train_config.log_interval == 0 and batch_idx > 0:
            print(
                'Train Epoch: {} [{}/{}] Loss: {:.6f} Acc: {:.4f}'.format(
                    epoch_idx, batch_idx * len(data), len(train_loader.dataset), loss.item(), acc
                )
            )

    epoch_loss = batch_loss.mean()
    epoch_acc = batch_acc.mean()
    return epoch_loss, epoch_acc

# %% [markdown]
# # <font style="color:blue">8. Validation</font>
#
# After every few epochs **`validation`** will be called with the `trained model` and `test_loader` to get validation loss and accuracy.

# %%
def validate(
    train_config: TrainingConfiguration,
    model: nn.Module,
    test_loader: torch.utils.data.DataLoader,
) -> float:
    model.eval()
    test_loss = 0
    count_corect_predictions = 0
    for data, target in test_loader:
        indx_target = target.clone()
        data = data.to(train_config.device)

        target = target.to(train_config.device)

        output = model(data)
        # add loss for each mini batch
        test_loss += F.cross_entropy(output, target).item()

        # Score to probability using softmax
        prob = F.softmax(output, dim=1)

        # get the index of the max probability
        pred = prob.data.max(dim=1)[1]

        # add correct prediction count
        count_corect_predictions += pred.cpu().eq(indx_target).sum()

    # average over number of mini-batches
    test_loss = test_loss / len(test_loader)

    # average over number of dataset
    accuracy = 100. * count_corect_predictions / len(test_loader.dataset)

    print(
        '\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, count_corect_predictions, len(test_loader.dataset), accuracy
        )
    )
    return test_loss, accuracy/100.0

# %% [markdown]
# # <font style="color:blue">9. Saving the Model</font>

# %%
def save_model(model, device, model_dir='models', model_file_name='cifar10_cnn_model.pt'):


    if not os.path.exists(model_dir):
        os.makedirs(model_dir)

    model_path = os.path.join(model_dir, model_file_name)

    # make sure you transfer the model to cpu.
    if device == 'cuda':
        model.to('cpu')

    # save the state_dict
    if int(torch.__version__.split('.')[1]) >= 6:
        torch.save(model.state_dict(), model_path, _use_new_zipfile_serialization=False)

    else:
        torch.save(model.state_dict(), model_path)

    if device == 'cuda':
        model.to('cuda')

    return

# %% [markdown]
# # <font style="color:blue">10. Main</font>
#
# In this section of code, we use the configuration parameters defined above and start the training. Here are the important actions being taken in the code below:
#
# 1. Set up system parameters like CPU/GPU, number of threads etc
# 1. Load the data using dataloaders
# 1. Create an instance of the LeNet model
# 1. Specify optimizer to use.
# 1. Set up variables to track loss and accuracy and start training.
# 1. If loss decreases, saving the model

# %%
def main(system_configuration=SystemConfiguration(), training_configuration=TrainingConfiguration()):

    # system configuration
    setup_system(system_configuration)

    # batch size
    batch_size_to_set = training_configuration.batch_size
    # num_workers
    num_workers_to_set = training_configuration.num_workers
    # epochs
    epoch_num_to_set = training_configuration.epochs_count

    # if GPU is available use training config,
    # else lowers batch_size, num_workers and epochs count
    if torch.cuda.is_available():
        device = "cuda"
    else:
        device = "cpu"
        num_workers_to_set = 2

    # data loader
    train_loader, test_loader = get_data(
        batch_size=training_configuration.batch_size,
        data_root=training_configuration.data_root,
        num_workers=num_workers_to_set
    )

    # Update training configuration
    training_configuration = TrainingConfiguration(
        device=device,
        num_workers=num_workers_to_set
    )

    # initiate model
    model = MyModel()

    # send model to device (GPU/CPU)
    model.to(training_configuration.device)

    # optimizer
    optimizer = optim.SGD(
        model.parameters(),
        lr=training_configuration.learning_rate
    )

    best_loss = torch.tensor(np.inf)
    best_accuracy = torch.tensor(0)

    # epoch train/test loss
    epoch_train_loss = np.array([])
    epoch_test_loss = np.array([])

    # epch train/test accuracy
    epoch_train_acc = np.array([])
    epoch_test_acc = np.array([])

    # trainig time measurement
    t_begin = time.time()
    for epoch in range(training_configuration.epochs_count):

        train_loss, train_acc = train(training_configuration, model, optimizer, train_loader, epoch)

        epoch_train_loss = np.append(epoch_train_loss, [train_loss])

        epoch_train_acc = np.append(epoch_train_acc, [train_acc])

        elapsed_time = time.time() - t_begin
        speed_epoch = elapsed_time / (epoch + 1)
        speed_batch = speed_epoch / len(train_loader)
        eta = speed_epoch * training_configuration.epochs_count - elapsed_time

        print(
            "Elapsed {:.2f}s, {:.2f} s/epoch, {:.2f} s/batch, ets {:.2f}s".format(
                elapsed_time, speed_epoch, speed_batch, eta
            )
        )

        if epoch % training_configuration.test_interval == 0:
            current_loss, current_accuracy = validate(training_configuration, model, test_loader)

            epoch_test_loss = np.append(epoch_test_loss, [current_loss])

            epoch_test_acc = np.append(epoch_test_acc, [current_accuracy])

            if current_loss < best_loss:
                best_loss = current_loss

            if current_accuracy > best_accuracy:
                best_accuracy = current_accuracy
                print('Accuracy improved, saving the model.\n')
                save_model(model, device)


    print("Total time: {:.2f}, Best Loss: {:.3f}, Best Accuracy: {:.3f}".format(time.time() - t_begin, best_loss,
                                                                                best_accuracy))

    return model, epoch_train_loss, epoch_train_acc, epoch_test_loss, epoch_test_acc

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %% [markdown]
# # <font style="color:blue">Step 11: Start Training</font>
# This is where you start the training. You may see that the training does not converge or does not give a good accuracy. You need to change
# - In Step 1: the network architecture and add a few more layers or more nodes to the already existing layers
# - In Step 5: training parameters such as learning rate or batch_size or epochs so that the network converges or run the network for longer so that it gets more time to fit the data
#
# **You need to make sure that the accuracy at the end is at least 75%.**

# %%
if required_training:
    model, epoch_train_loss, epoch_train_acc, epoch_test_loss, epoch_test_acc = main()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ../data/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:05<00:00, 31.7MB/s]
# Extracting ../data/cifar-10-python.tar.gz to ../data
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Files already downloaded and verified
# Train Epoch: 0 [12800/50000] Loss: 2.322724 Acc: 0.1328
# Train Epoch: 0 [25600/50000] Loss: 2.294004 Acc: 0.0938
# Train Epoch: 0 [38400/50000] Loss: 2.320019 Acc: 0.1250
# Elapsed 16.74s, 16.74 s/epoch, 0.04 s/batch, ets 7515.23s
#
# Test set: Average loss: 2.2987, Accuracy: 1350/10000 (14%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 1 [12800/50000] Loss: 2.304035 Acc: 0.1484
# Train Epoch: 1 [25600/50000] Loss: 2.293556 Acc: 0.1250
# Train Epoch: 1 [38400/50000] Loss: 2.282239 Acc: 0.1172
# Elapsed 34.44s, 17.22 s/epoch, 0.04 s/batch, ets 7715.45s
#
# Test set: Average loss: 2.2864, Accuracy: 1508/10000 (15%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 2 [12800/50000] Loss: 2.291746 Acc: 0.1641
# Train Epoch: 2 [25600/50000] Loss: 2.285877 Acc: 0.1406
# Train Epoch: 2 [38400/50000] Loss: 2.301186 Acc: 0.1094
# Elapsed 51.65s, 17.22 s/epoch, 0.04 s/batch, ets 7695.75s
#
# Test set: Average loss: 2.2758, Accuracy: 1712/10000 (17%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 3 [12800/50000] Loss: 2.289166 Acc: 0.1562
# Train Epoch: 3 [25600/50000] Loss: 2.279488 Acc: 0.1562
# Train Epoch: 3 [38400/50000] Loss: 2.295623 Acc: 0.1250
# Elapsed 70.11s, 17.53 s/epoch, 0.04 s/batch, ets 7817.80s
#
# Test set: Average loss: 2.2656, Accuracy: 1883/10000 (19%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 4 [12800/50000] Loss: 2.275041 Acc: 0.1484
# Train Epoch: 4 [25600/50000] Loss: 2.291152 Acc: 0.1172
# Train Epoch: 4 [38400/50000] Loss: 2.275113 Acc: 0.1406
# Elapsed 87.59s, 17.52 s/epoch, 0.04 s/batch, ets 7795.60s
#
# Test set: Average loss: 2.2550, Accuracy: 2025/10000 (20%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 5 [12800/50000] Loss: 2.266604 Acc: 0.1875
# Train Epoch: 5 [25600/50000] Loss: 2.257502 Acc: 0.1406
# Train Epoch: 5 [38400/50000] Loss: 2.247520 Acc: 0.1719
# Elapsed 105.25s, 17.54 s/epoch, 0.04 s/batch, ets 7788.65s
#
# Test set: Average loss: 2.2444, Accuracy: 2218/10000 (22%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 6 [12800/50000] Loss: 2.248227 Acc: 0.1562
# Train Epoch: 6 [25600/50000] Loss: 2.271345 Acc: 0.1484
# Train Epoch: 6 [38400/50000] Loss: 2.269335 Acc: 0.1328
# Elapsed 124.66s, 17.81 s/epoch, 0.05 s/batch, ets 7889.41s
#
# Test set: Average loss: 2.2325, Accuracy: 2374/10000 (24%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 7 [12800/50000] Loss: 2.253436 Acc: 0.1641
# Train Epoch: 7 [25600/50000] Loss: 2.239043 Acc: 0.2266
# Train Epoch: 7 [38400/50000] Loss: 2.238424 Acc: 0.2031
# Elapsed 142.37s, 17.80 s/epoch, 0.05 s/batch, ets 7865.83s
#
# Test set: Average loss: 2.2186, Accuracy: 2521/10000 (25%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 8 [12800/50000] Loss: 2.227616 Acc: 0.1953
# Train Epoch: 8 [25600/50000] Loss: 2.221920 Acc: 0.1953
# Train Epoch: 8 [38400/50000] Loss: 2.215896 Acc: 0.1641
# Elapsed 161.38s, 17.93 s/epoch, 0.05 s/batch, ets 7907.47s
#
# Test set: Average loss: 2.2048, Accuracy: 2680/10000 (27%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 9 [12800/50000] Loss: 2.216408 Acc: 0.1953
# Train Epoch: 9 [25600/50000] Loss: 2.227048 Acc: 0.1797
# Train Epoch: 9 [38400/50000] Loss: 2.216128 Acc: 0.1484
# Elapsed 179.11s, 17.91 s/epoch, 0.05 s/batch, ets 7880.80s
#
# Test set: Average loss: 2.1885, Accuracy: 2755/10000 (28%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 10 [12800/50000] Loss: 2.227879 Acc: 0.2266
# Train Epoch: 10 [25600/50000] Loss: 2.216544 Acc: 0.2109
# Train Epoch: 10 [38400/50000] Loss: 2.207852 Acc: 0.1562
# Elapsed 197.39s, 17.94 s/epoch, 0.05 s/batch, ets 7877.55s
#
# Test set: Average loss: 2.1722, Accuracy: 2847/10000 (28%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 11 [12800/50000] Loss: 2.208341 Acc: 0.2266
# Train Epoch: 11 [25600/50000] Loss: 2.189935 Acc: 0.2500
# Train Epoch: 11 [38400/50000] Loss: 2.207886 Acc: 0.2578
# Elapsed 215.23s, 17.94 s/epoch, 0.05 s/batch, ets 7855.75s
#
# Test set: Average loss: 2.1542, Accuracy: 2948/10000 (29%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 12 [12800/50000] Loss: 2.146202 Acc: 0.2422
# Train Epoch: 12 [25600/50000] Loss: 2.187105 Acc: 0.1953
# Train Epoch: 12 [38400/50000] Loss: 2.128921 Acc: 0.2656
# Elapsed 232.75s, 17.90 s/epoch, 0.05 s/batch, ets 7824.06s
#
# Test set: Average loss: 2.1360, Accuracy: 2992/10000 (30%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 13 [12800/50000] Loss: 2.148985 Acc: 0.2656
# Train Epoch: 13 [25600/50000] Loss: 2.128501 Acc: 0.2656
# Train Epoch: 13 [38400/50000] Loss: 2.200469 Acc: 0.2422
# Elapsed 251.42s, 17.96 s/epoch, 0.05 s/batch, ets 7829.79s
#
# Test set: Average loss: 2.1124, Accuracy: 3045/10000 (30%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 14 [12800/50000] Loss: 2.116338 Acc: 0.2422
# Train Epoch: 14 [25600/50000] Loss: 2.178627 Acc: 0.2188
# Train Epoch: 14 [38400/50000] Loss: 2.122146 Acc: 0.2266
# Elapsed 269.14s, 17.94 s/epoch, 0.05 s/batch, ets 7805.16s
#
# Test set: Average loss: 2.0923, Accuracy: 3072/10000 (31%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 15 [12800/50000] Loss: 2.101274 Acc: 0.2812
# Train Epoch: 15 [25600/50000] Loss: 2.088595 Acc: 0.2969
# Train Epoch: 15 [38400/50000] Loss: 2.154616 Acc: 0.1797
# Elapsed 287.32s, 17.96 s/epoch, 0.05 s/batch, ets 7793.67s
#
# Test set: Average loss: 2.0730, Accuracy: 3111/10000 (31%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 16 [12800/50000] Loss: 2.145288 Acc: 0.1953
# Train Epoch: 16 [25600/50000] Loss: 2.106375 Acc: 0.2266
# Train Epoch: 16 [38400/50000] Loss: 2.104118 Acc: 0.2109
# Elapsed 305.14s, 17.95 s/epoch, 0.05 s/batch, ets 7772.16s
#
# Test set: Average loss: 2.0475, Accuracy: 3157/10000 (32%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 17 [12800/50000] Loss: 2.040282 Acc: 0.2734
# Train Epoch: 17 [25600/50000] Loss: 2.097918 Acc: 0.2266
# Train Epoch: 17 [38400/50000] Loss: 2.084614 Acc: 0.2500
# Elapsed 322.53s, 17.92 s/epoch, 0.05 s/batch, ets 7740.76s
#
# Test set: Average loss: 2.0271, Accuracy: 3218/10000 (32%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 18 [12800/50000] Loss: 2.078267 Acc: 0.2344
# Train Epoch: 18 [25600/50000] Loss: 2.098374 Acc: 0.2344
# Train Epoch: 18 [38400/50000] Loss: 2.081574 Acc: 0.1953
# Elapsed 341.17s, 17.96 s/epoch, 0.05 s/batch, ets 7739.11s
#
# Test set: Average loss: 2.0038, Accuracy: 3273/10000 (33%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 19 [12800/50000] Loss: 2.038903 Acc: 0.2734
# Train Epoch: 19 [25600/50000] Loss: 2.006830 Acc: 0.3125
# Train Epoch: 19 [38400/50000] Loss: 2.096791 Acc: 0.1719
# Elapsed 358.59s, 17.93 s/epoch, 0.05 s/batch, ets 7709.77s
#
# Test set: Average loss: 1.9807, Accuracy: 3296/10000 (33%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 20 [12800/50000] Loss: 2.063922 Acc: 0.2500
# Train Epoch: 20 [25600/50000] Loss: 2.053467 Acc: 0.2109
# Train Epoch: 20 [38400/50000] Loss: 1.981733 Acc: 0.3203
# Elapsed 376.71s, 17.94 s/epoch, 0.05 s/batch, ets 7695.66s
#
# Test set: Average loss: 1.9615, Accuracy: 3345/10000 (33%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 21 [12800/50000] Loss: 2.010600 Acc: 0.2422
# Train Epoch: 21 [25600/50000] Loss: 1.996451 Acc: 0.2969
# Train Epoch: 21 [38400/50000] Loss: 2.014750 Acc: 0.2422
# Elapsed 395.56s, 17.98 s/epoch, 0.05 s/batch, ets 7695.51s
#
# Test set: Average loss: 1.9406, Accuracy: 3390/10000 (34%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 22 [12800/50000] Loss: 2.003803 Acc: 0.2969
# Train Epoch: 22 [25600/50000] Loss: 1.964365 Acc: 0.2891
# Train Epoch: 22 [38400/50000] Loss: 2.091827 Acc: 0.1953
# Elapsed 413.08s, 17.96 s/epoch, 0.05 s/batch, ets 7668.88s
#
# Test set: Average loss: 1.9178, Accuracy: 3461/10000 (35%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 23 [12800/50000] Loss: 2.057333 Acc: 0.2031
# Train Epoch: 23 [25600/50000] Loss: 1.988133 Acc: 0.2578
# Train Epoch: 23 [38400/50000] Loss: 1.940737 Acc: 0.2422
# Elapsed 431.79s, 17.99 s/epoch, 0.05 s/batch, ets 7664.27s
#
# Test set: Average loss: 1.9000, Accuracy: 3486/10000 (35%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 24 [12800/50000] Loss: 1.955072 Acc: 0.2812
# Train Epoch: 24 [25600/50000] Loss: 1.936126 Acc: 0.3125
# Train Epoch: 24 [38400/50000] Loss: 1.900888 Acc: 0.2891
# Elapsed 449.34s, 17.97 s/epoch, 0.05 s/batch, ets 7638.76s
#
# Test set: Average loss: 1.8821, Accuracy: 3561/10000 (36%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 25 [12800/50000] Loss: 1.911586 Acc: 0.2656
# Train Epoch: 25 [25600/50000] Loss: 1.870949 Acc: 0.3203
# Train Epoch: 25 [38400/50000] Loss: 1.951745 Acc: 0.2891
# Elapsed 467.37s, 17.98 s/epoch, 0.05 s/batch, ets 7621.78s
#
# Test set: Average loss: 1.8646, Accuracy: 3629/10000 (36%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 26 [12800/50000] Loss: 1.963560 Acc: 0.2734
# Train Epoch: 26 [25600/50000] Loss: 2.009745 Acc: 0.1875
# Train Epoch: 26 [38400/50000] Loss: 1.921879 Acc: 0.2891
# Elapsed 485.46s, 17.98 s/epoch, 0.05 s/batch, ets 7605.48s
#
# Test set: Average loss: 1.8469, Accuracy: 3654/10000 (37%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 27 [12800/50000] Loss: 1.850985 Acc: 0.3359
# Train Epoch: 27 [25600/50000] Loss: 1.892228 Acc: 0.3125
# Train Epoch: 27 [38400/50000] Loss: 1.884195 Acc: 0.3516
# Elapsed 503.00s, 17.96 s/epoch, 0.05 s/batch, ets 7580.88s
#
# Test set: Average loss: 1.8308, Accuracy: 3709/10000 (37%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 28 [12800/50000] Loss: 1.976610 Acc: 0.2578
# Train Epoch: 28 [25600/50000] Loss: 1.917830 Acc: 0.2969
# Train Epoch: 28 [38400/50000] Loss: 1.916152 Acc: 0.2656
# Elapsed 521.55s, 17.98 s/epoch, 0.05 s/batch, ets 7571.47s
#
# Test set: Average loss: 1.8155, Accuracy: 3730/10000 (37%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 29 [12800/50000] Loss: 1.885380 Acc: 0.3047
# Train Epoch: 29 [25600/50000] Loss: 1.866315 Acc: 0.2500
# Train Epoch: 29 [38400/50000] Loss: 1.826394 Acc: 0.3516
# Elapsed 538.88s, 17.96 s/epoch, 0.05 s/batch, ets 7544.30s
#
# Test set: Average loss: 1.8043, Accuracy: 3762/10000 (38%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 30 [12800/50000] Loss: 1.848656 Acc: 0.2969
# Train Epoch: 30 [25600/50000] Loss: 1.879470 Acc: 0.3281
# Train Epoch: 30 [38400/50000] Loss: 1.840171 Acc: 0.3047
# Elapsed 556.62s, 17.96 s/epoch, 0.05 s/batch, ets 7523.40s
#
# Test set: Average loss: 1.7881, Accuracy: 3810/10000 (38%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 31 [12800/50000] Loss: 1.844631 Acc: 0.3125
# Train Epoch: 31 [25600/50000] Loss: 1.917928 Acc: 0.2734
# Train Epoch: 31 [38400/50000] Loss: 1.847304 Acc: 0.2969
# Elapsed 574.56s, 17.96 s/epoch, 0.05 s/batch, ets 7505.24s
#
# Test set: Average loss: 1.7759, Accuracy: 3856/10000 (39%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 32 [12800/50000] Loss: 1.932460 Acc: 0.2578
# Train Epoch: 32 [25600/50000] Loss: 1.803400 Acc: 0.3047
# Train Epoch: 32 [38400/50000] Loss: 1.833069 Acc: 0.3516
# Elapsed 592.09s, 17.94 s/epoch, 0.05 s/batch, ets 7481.85s
#
# Test set: Average loss: 1.7624, Accuracy: 3888/10000 (39%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 33 [12800/50000] Loss: 1.884783 Acc: 0.2812
# Train Epoch: 33 [25600/50000] Loss: 1.937306 Acc: 0.2812
# Train Epoch: 33 [38400/50000] Loss: 1.816209 Acc: 0.2969
# Elapsed 610.81s, 17.97 s/epoch, 0.05 s/batch, ets 7473.48s
#
# Test set: Average loss: 1.7500, Accuracy: 3919/10000 (39%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 34 [12800/50000] Loss: 1.850670 Acc: 0.2500
# Train Epoch: 34 [25600/50000] Loss: 1.871292 Acc: 0.3047
# Train Epoch: 34 [38400/50000] Loss: 1.801159 Acc: 0.3281
# Elapsed 628.20s, 17.95 s/epoch, 0.05 s/batch, ets 7448.70s
#
# Test set: Average loss: 1.7377, Accuracy: 3967/10000 (40%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 35 [12800/50000] Loss: 1.878162 Acc: 0.2812
# Train Epoch: 35 [25600/50000] Loss: 1.918439 Acc: 0.2500
# Train Epoch: 35 [38400/50000] Loss: 1.679904 Acc: 0.3906
# Elapsed 645.81s, 17.94 s/epoch, 0.05 s/batch, ets 7426.84s
#
# Test set: Average loss: 1.7266, Accuracy: 4000/10000 (40%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 36 [12800/50000] Loss: 2.011503 Acc: 0.2500
# Train Epoch: 36 [25600/50000] Loss: 1.823668 Acc: 0.2969
# Train Epoch: 36 [38400/50000] Loss: 1.796974 Acc: 0.3594
# Elapsed 665.29s, 17.98 s/epoch, 0.05 s/batch, ets 7426.11s
#
# Test set: Average loss: 1.7148, Accuracy: 4025/10000 (40%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 37 [12800/50000] Loss: 1.710172 Acc: 0.3750
# Train Epoch: 37 [25600/50000] Loss: 1.775186 Acc: 0.3203
# Train Epoch: 37 [38400/50000] Loss: 1.772618 Acc: 0.3438
# Elapsed 683.74s, 17.99 s/epoch, 0.05 s/batch, ets 7413.17s
#
# Test set: Average loss: 1.7053, Accuracy: 4046/10000 (40%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 38 [12800/50000] Loss: 1.817875 Acc: 0.3125
# Train Epoch: 38 [25600/50000] Loss: 1.860088 Acc: 0.3359
# Train Epoch: 38 [38400/50000] Loss: 1.800352 Acc: 0.2969
# Elapsed 702.59s, 18.02 s/epoch, 0.05 s/batch, ets 7404.20s
#
# Test set: Average loss: 1.6948, Accuracy: 4056/10000 (41%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 39 [12800/50000] Loss: 1.801112 Acc: 0.2500
# Train Epoch: 39 [25600/50000] Loss: 1.738094 Acc: 0.2969
# Train Epoch: 39 [38400/50000] Loss: 1.807853 Acc: 0.3125
# Elapsed 720.53s, 18.01 s/epoch, 0.05 s/batch, ets 7385.39s
#
# Test set: Average loss: 1.6845, Accuracy: 4096/10000 (41%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 40 [12800/50000] Loss: 1.719840 Acc: 0.3438
# Train Epoch: 40 [25600/50000] Loss: 1.665750 Acc: 0.4141
# Train Epoch: 40 [38400/50000] Loss: 1.775147 Acc: 0.3203
# Elapsed 738.80s, 18.02 s/epoch, 0.05 s/batch, ets 7370.01s
#
# Test set: Average loss: 1.6763, Accuracy: 4120/10000 (41%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 41 [12800/50000] Loss: 1.793679 Acc: 0.4141
# Train Epoch: 41 [25600/50000] Loss: 1.740332 Acc: 0.2891
# Train Epoch: 41 [38400/50000] Loss: 1.730245 Acc: 0.2891
# Elapsed 757.35s, 18.03 s/epoch, 0.05 s/batch, ets 7357.09s
#
# Test set: Average loss: 1.6666, Accuracy: 4134/10000 (41%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 42 [12800/50000] Loss: 1.869529 Acc: 0.2812
# Train Epoch: 42 [25600/50000] Loss: 1.822858 Acc: 0.2812
# Train Epoch: 42 [38400/50000] Loss: 1.730258 Acc: 0.3672
# Elapsed 775.20s, 18.03 s/epoch, 0.05 s/batch, ets 7337.32s
#
# Test set: Average loss: 1.6581, Accuracy: 4170/10000 (42%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 43 [12800/50000] Loss: 1.727471 Acc: 0.2969
# Train Epoch: 43 [25600/50000] Loss: 1.757356 Acc: 0.3359
# Train Epoch: 43 [38400/50000] Loss: 1.637742 Acc: 0.4062
# Elapsed 793.78s, 18.04 s/epoch, 0.05 s/batch, ets 7324.39s
#
# Test set: Average loss: 1.6489, Accuracy: 4193/10000 (42%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 44 [12800/50000] Loss: 1.703561 Acc: 0.3203
# Train Epoch: 44 [25600/50000] Loss: 1.688480 Acc: 0.4297
# Train Epoch: 44 [38400/50000] Loss: 1.725449 Acc: 0.3594
# Elapsed 811.26s, 18.03 s/epoch, 0.05 s/batch, ets 7301.38s
#
# Test set: Average loss: 1.6411, Accuracy: 4222/10000 (42%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 45 [12800/50000] Loss: 1.652181 Acc: 0.3906
# Train Epoch: 45 [25600/50000] Loss: 1.613290 Acc: 0.4141
# Train Epoch: 45 [38400/50000] Loss: 1.785913 Acc: 0.3203
# Elapsed 829.32s, 18.03 s/epoch, 0.05 s/batch, ets 7283.63s
#
# Test set: Average loss: 1.6327, Accuracy: 4247/10000 (42%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 46 [12800/50000] Loss: 1.679777 Acc: 0.3984
# Train Epoch: 46 [25600/50000] Loss: 1.691957 Acc: 0.3750
# Train Epoch: 46 [38400/50000] Loss: 1.755399 Acc: 0.3594
# Elapsed 847.57s, 18.03 s/epoch, 0.05 s/batch, ets 7267.44s
#
# Test set: Average loss: 1.6255, Accuracy: 4278/10000 (43%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 47 [12800/50000] Loss: 1.744793 Acc: 0.3047
# Train Epoch: 47 [25600/50000] Loss: 1.694353 Acc: 0.3281
# Train Epoch: 47 [38400/50000] Loss: 1.678386 Acc: 0.3750
# Elapsed 865.08s, 18.02 s/epoch, 0.05 s/batch, ets 7245.01s
#
# Test set: Average loss: 1.6163, Accuracy: 4286/10000 (43%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 48 [12800/50000] Loss: 1.681961 Acc: 0.3281
# Train Epoch: 48 [25600/50000] Loss: 1.682976 Acc: 0.4297
# Train Epoch: 48 [38400/50000] Loss: 1.754775 Acc: 0.3516
# Elapsed 883.58s, 18.03 s/epoch, 0.05 s/batch, ets 7230.96s
#
# Test set: Average loss: 1.6104, Accuracy: 4303/10000 (43%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 49 [12800/50000] Loss: 1.764348 Acc: 0.3047
# Train Epoch: 49 [25600/50000] Loss: 1.725950 Acc: 0.3516
# Train Epoch: 49 [38400/50000] Loss: 1.787234 Acc: 0.3203
# Elapsed 900.97s, 18.02 s/epoch, 0.05 s/batch, ets 7207.73s
#
# Test set: Average loss: 1.6018, Accuracy: 4314/10000 (43%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 50 [12800/50000] Loss: 1.690813 Acc: 0.4141
# Train Epoch: 50 [25600/50000] Loss: 1.682855 Acc: 0.3828
# Train Epoch: 50 [38400/50000] Loss: 1.762168 Acc: 0.3359
# Elapsed 919.44s, 18.03 s/epoch, 0.05 s/batch, ets 7193.27s
#
# Test set: Average loss: 1.5950, Accuracy: 4342/10000 (43%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 51 [12800/50000] Loss: 1.642379 Acc: 0.4375
# Train Epoch: 51 [25600/50000] Loss: 1.826509 Acc: 0.2734
# Train Epoch: 51 [38400/50000] Loss: 1.561117 Acc: 0.3906
# Elapsed 938.31s, 18.04 s/epoch, 0.05 s/batch, ets 7181.69s
#
# Test set: Average loss: 1.5877, Accuracy: 4356/10000 (44%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 52 [12800/50000] Loss: 1.594233 Acc: 0.4297
# Train Epoch: 52 [25600/50000] Loss: 1.631181 Acc: 0.3047
# Train Epoch: 52 [38400/50000] Loss: 1.773721 Acc: 0.3047
# Elapsed 956.02s, 18.04 s/epoch, 0.05 s/batch, ets 7161.13s
#
# Test set: Average loss: 1.5798, Accuracy: 4363/10000 (44%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 53 [12800/50000] Loss: 1.657012 Acc: 0.3281
# Train Epoch: 53 [25600/50000] Loss: 1.675221 Acc: 0.3984
# Train Epoch: 53 [38400/50000] Loss: 1.739250 Acc: 0.3203
# Elapsed 974.73s, 18.05 s/epoch, 0.05 s/batch, ets 7148.04s
#
# Test set: Average loss: 1.5746, Accuracy: 4392/10000 (44%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 54 [12800/50000] Loss: 1.661973 Acc: 0.3828
# Train Epoch: 54 [25600/50000] Loss: 1.644219 Acc: 0.3750
# Train Epoch: 54 [38400/50000] Loss: 1.756920 Acc: 0.3203
# Elapsed 992.43s, 18.04 s/epoch, 0.05 s/batch, ets 7127.43s
#
# Test set: Average loss: 1.5650, Accuracy: 4406/10000 (44%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 55 [12800/50000] Loss: 1.678409 Acc: 0.3516
# Train Epoch: 55 [25600/50000] Loss: 1.777677 Acc: 0.3594
# Train Epoch: 55 [38400/50000] Loss: 1.657061 Acc: 0.3281
# Elapsed 1010.59s, 18.05 s/epoch, 0.05 s/batch, ets 7110.21s
#
# Test set: Average loss: 1.5597, Accuracy: 4437/10000 (44%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 56 [12800/50000] Loss: 1.721282 Acc: 0.3203
# Train Epoch: 56 [25600/50000] Loss: 1.664973 Acc: 0.4062
# Train Epoch: 56 [38400/50000] Loss: 1.727472 Acc: 0.3281
# Elapsed 1028.88s, 18.05 s/epoch, 0.05 s/batch, ets 7093.82s
#
# Test set: Average loss: 1.5517, Accuracy: 4444/10000 (44%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 57 [12800/50000] Loss: 1.640790 Acc: 0.4219
# Train Epoch: 57 [25600/50000] Loss: 1.717871 Acc: 0.3281
# Train Epoch: 57 [38400/50000] Loss: 1.596616 Acc: 0.3359
# Elapsed 1046.85s, 18.05 s/epoch, 0.05 s/batch, ets 7075.26s
#
# Test set: Average loss: 1.5455, Accuracy: 4455/10000 (45%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 58 [12800/50000] Loss: 1.702468 Acc: 0.3047
# Train Epoch: 58 [25600/50000] Loss: 1.727314 Acc: 0.3906
# Train Epoch: 58 [38400/50000] Loss: 1.689411 Acc: 0.3516
# Elapsed 1065.81s, 18.06 s/epoch, 0.05 s/batch, ets 7063.24s
#
# Test set: Average loss: 1.5396, Accuracy: 4473/10000 (45%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 59 [12800/50000] Loss: 1.630905 Acc: 0.3984
# Train Epoch: 59 [25600/50000] Loss: 1.639213 Acc: 0.3594
# Train Epoch: 59 [38400/50000] Loss: 1.687446 Acc: 0.3516
# Elapsed 1083.54s, 18.06 s/epoch, 0.05 s/batch, ets 7043.03s
#
# Test set: Average loss: 1.5324, Accuracy: 4504/10000 (45%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 60 [12800/50000] Loss: 1.643068 Acc: 0.4141
# Train Epoch: 60 [25600/50000] Loss: 1.636222 Acc: 0.3906
# Train Epoch: 60 [38400/50000] Loss: 1.670205 Acc: 0.4219
# Elapsed 1101.99s, 18.07 s/epoch, 0.05 s/batch, ets 7027.47s
#
# Test set: Average loss: 1.5254, Accuracy: 4523/10000 (45%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 61 [12800/50000] Loss: 1.508345 Acc: 0.5312
# Train Epoch: 61 [25600/50000] Loss: 1.660261 Acc: 0.3594
# Train Epoch: 61 [38400/50000] Loss: 1.528249 Acc: 0.4375
# Elapsed 1119.51s, 18.06 s/epoch, 0.05 s/batch, ets 7005.96s
#
# Test set: Average loss: 1.5197, Accuracy: 4539/10000 (45%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 62 [12800/50000] Loss: 1.616832 Acc: 0.4141
# Train Epoch: 62 [25600/50000] Loss: 1.636150 Acc: 0.3516
# Train Epoch: 62 [38400/50000] Loss: 1.652706 Acc: 0.4219
# Elapsed 1137.24s, 18.05 s/epoch, 0.05 s/batch, ets 6985.93s
#
# Test set: Average loss: 1.5143, Accuracy: 4552/10000 (46%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 63 [12800/50000] Loss: 1.555831 Acc: 0.4062
# Train Epoch: 63 [25600/50000] Loss: 1.576234 Acc: 0.4297
# Train Epoch: 63 [38400/50000] Loss: 1.713645 Acc: 0.3203
# Elapsed 1155.74s, 18.06 s/epoch, 0.05 s/batch, ets 6970.57s
#
# Test set: Average loss: 1.5070, Accuracy: 4568/10000 (46%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 64 [12800/50000] Loss: 1.598927 Acc: 0.4141
# Train Epoch: 64 [25600/50000] Loss: 1.601164 Acc: 0.4219
# Train Epoch: 64 [38400/50000] Loss: 1.689712 Acc: 0.3594
# Elapsed 1173.52s, 18.05 s/epoch, 0.05 s/batch, ets 6950.82s
#
# Test set: Average loss: 1.5001, Accuracy: 4584/10000 (46%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 65 [12800/50000] Loss: 1.464496 Acc: 0.3906
# Train Epoch: 65 [25600/50000] Loss: 1.643253 Acc: 0.3438
# Train Epoch: 65 [38400/50000] Loss: 1.546017 Acc: 0.4141
# Elapsed 1192.88s, 18.07 s/epoch, 0.05 s/batch, ets 6940.42s
#
# Test set: Average loss: 1.4944, Accuracy: 4601/10000 (46%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 66 [12800/50000] Loss: 1.574954 Acc: 0.3438
# Train Epoch: 66 [25600/50000] Loss: 1.638656 Acc: 0.4062
# Train Epoch: 66 [38400/50000] Loss: 1.705217 Acc: 0.3047
# Elapsed 1210.47s, 18.07 s/epoch, 0.05 s/batch, ets 6919.55s
#
# Test set: Average loss: 1.4884, Accuracy: 4611/10000 (46%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 67 [12800/50000] Loss: 1.692983 Acc: 0.3281
# Train Epoch: 67 [25600/50000] Loss: 1.559836 Acc: 0.3750
# Train Epoch: 67 [38400/50000] Loss: 1.628447 Acc: 0.3750
# Elapsed 1228.22s, 18.06 s/epoch, 0.05 s/batch, ets 6899.71s
#
# Test set: Average loss: 1.4827, Accuracy: 4648/10000 (46%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 68 [12800/50000] Loss: 1.609484 Acc: 0.3984
# Train Epoch: 68 [25600/50000] Loss: 1.606999 Acc: 0.4375
# Train Epoch: 68 [38400/50000] Loss: 1.601523 Acc: 0.3828
# Elapsed 1246.97s, 18.07 s/epoch, 0.05 s/batch, ets 6885.45s
#
# Test set: Average loss: 1.4765, Accuracy: 4667/10000 (47%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 69 [12800/50000] Loss: 1.534289 Acc: 0.3438
# Train Epoch: 69 [25600/50000] Loss: 1.664991 Acc: 0.3594
# Train Epoch: 69 [38400/50000] Loss: 1.539433 Acc: 0.4219
# Elapsed 1264.79s, 18.07 s/epoch, 0.05 s/batch, ets 6865.98s
#
# Test set: Average loss: 1.4701, Accuracy: 4675/10000 (47%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 70 [12800/50000] Loss: 1.574944 Acc: 0.3984
# Train Epoch: 70 [25600/50000] Loss: 1.597543 Acc: 0.4062
# Train Epoch: 70 [38400/50000] Loss: 1.548407 Acc: 0.4531
# Elapsed 1283.36s, 18.08 s/epoch, 0.05 s/batch, ets 6850.63s
#
# Test set: Average loss: 1.4654, Accuracy: 4686/10000 (47%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 71 [12800/50000] Loss: 1.509383 Acc: 0.4766
# Train Epoch: 71 [25600/50000] Loss: 1.470495 Acc: 0.4375
# Train Epoch: 71 [38400/50000] Loss: 1.628537 Acc: 0.3672
# Elapsed 1300.91s, 18.07 s/epoch, 0.05 s/batch, ets 6829.78s
#
# Test set: Average loss: 1.4591, Accuracy: 4713/10000 (47%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 72 [12800/50000] Loss: 1.481623 Acc: 0.3984
# Train Epoch: 72 [25600/50000] Loss: 1.531947 Acc: 0.4219
# Train Epoch: 72 [38400/50000] Loss: 1.516338 Acc: 0.4766
# Elapsed 1318.78s, 18.07 s/epoch, 0.05 s/batch, ets 6810.69s
#
# Test set: Average loss: 1.4541, Accuracy: 4730/10000 (47%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 73 [12800/50000] Loss: 1.631397 Acc: 0.3438
# Train Epoch: 73 [25600/50000] Loss: 1.496563 Acc: 0.4141
# Train Epoch: 73 [38400/50000] Loss: 1.600918 Acc: 0.4219
# Elapsed 1337.38s, 18.07 s/epoch, 0.05 s/batch, ets 6795.33s
#
# Test set: Average loss: 1.4478, Accuracy: 4741/10000 (47%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 74 [12800/50000] Loss: 1.470172 Acc: 0.4922
# Train Epoch: 74 [25600/50000] Loss: 1.547895 Acc: 0.3906
# Train Epoch: 74 [38400/50000] Loss: 1.543810 Acc: 0.3906
# Elapsed 1354.92s, 18.07 s/epoch, 0.05 s/batch, ets 6774.62s
#
# Test set: Average loss: 1.4426, Accuracy: 4770/10000 (48%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 75 [12800/50000] Loss: 1.578926 Acc: 0.4141
# Train Epoch: 75 [25600/50000] Loss: 1.468699 Acc: 0.3984
# Train Epoch: 75 [38400/50000] Loss: 1.492569 Acc: 0.4297
# Elapsed 1373.26s, 18.07 s/epoch, 0.05 s/batch, ets 6757.89s
#
# Test set: Average loss: 1.4371, Accuracy: 4785/10000 (48%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 76 [12800/50000] Loss: 1.554121 Acc: 0.4375
# Train Epoch: 76 [25600/50000] Loss: 1.507918 Acc: 0.4688
# Train Epoch: 76 [38400/50000] Loss: 1.608080 Acc: 0.3516
# Elapsed 1390.94s, 18.06 s/epoch, 0.05 s/batch, ets 6737.92s
#
# Test set: Average loss: 1.4324, Accuracy: 4812/10000 (48%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 77 [12800/50000] Loss: 1.564182 Acc: 0.3516
# Train Epoch: 77 [25600/50000] Loss: 1.417331 Acc: 0.5078
# Train Epoch: 77 [38400/50000] Loss: 1.629259 Acc: 0.3828
# Elapsed 1408.60s, 18.06 s/epoch, 0.05 s/batch, ets 6717.92s
#
# Test set: Average loss: 1.4280, Accuracy: 4824/10000 (48%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 78 [12800/50000] Loss: 1.457303 Acc: 0.4219
# Train Epoch: 78 [25600/50000] Loss: 1.518294 Acc: 0.3828
# Train Epoch: 78 [38400/50000] Loss: 1.557617 Acc: 0.4375
# Elapsed 1426.94s, 18.06 s/epoch, 0.05 s/batch, ets 6701.21s
#
# Test set: Average loss: 1.4208, Accuracy: 4832/10000 (48%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 79 [12800/50000] Loss: 1.620191 Acc: 0.3750
# Train Epoch: 79 [25600/50000] Loss: 1.491244 Acc: 0.3906
# Train Epoch: 79 [38400/50000] Loss: 1.520695 Acc: 0.4141
# Elapsed 1444.62s, 18.06 s/epoch, 0.05 s/batch, ets 6681.39s
#
# Test set: Average loss: 1.4144, Accuracy: 4858/10000 (49%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 80 [12800/50000] Loss: 1.601078 Acc: 0.3359
# Train Epoch: 80 [25600/50000] Loss: 1.448750 Acc: 0.4375
# Train Epoch: 80 [38400/50000] Loss: 1.419371 Acc: 0.4609
# Elapsed 1463.75s, 18.07 s/epoch, 0.05 s/batch, ets 6668.21s
#
# Test set: Average loss: 1.4100, Accuracy: 4880/10000 (49%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 81 [12800/50000] Loss: 1.692528 Acc: 0.3281
# Train Epoch: 81 [25600/50000] Loss: 1.471026 Acc: 0.4453
# Train Epoch: 81 [38400/50000] Loss: 1.538080 Acc: 0.4609
# Elapsed 1481.48s, 18.07 s/epoch, 0.05 s/batch, ets 6648.61s
#
# Test set: Average loss: 1.4049, Accuracy: 4901/10000 (49%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 82 [12800/50000] Loss: 1.561054 Acc: 0.3828
# Train Epoch: 82 [25600/50000] Loss: 1.489311 Acc: 0.4453
# Train Epoch: 82 [38400/50000] Loss: 1.432644 Acc: 0.5000
# Elapsed 1499.24s, 18.06 s/epoch, 0.05 s/batch, ets 6629.17s
#
# Test set: Average loss: 1.3991, Accuracy: 4945/10000 (49%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 83 [12800/50000] Loss: 1.410496 Acc: 0.4688
# Train Epoch: 83 [25600/50000] Loss: 1.557872 Acc: 0.3750
# Train Epoch: 83 [38400/50000] Loss: 1.549375 Acc: 0.3672
# Elapsed 1517.34s, 18.06 s/epoch, 0.05 s/batch, ets 6611.29s
#
# Test set: Average loss: 1.3933, Accuracy: 4954/10000 (50%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 84 [12800/50000] Loss: 1.413566 Acc: 0.5391
# Train Epoch: 84 [25600/50000] Loss: 1.571019 Acc: 0.3594
# Train Epoch: 84 [38400/50000] Loss: 1.545438 Acc: 0.4297
# Elapsed 1534.98s, 18.06 s/epoch, 0.05 s/batch, ets 6591.38s
#
# Test set: Average loss: 1.3890, Accuracy: 4967/10000 (50%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 85 [12800/50000] Loss: 1.462156 Acc: 0.4219
# Train Epoch: 85 [25600/50000] Loss: 1.487941 Acc: 0.4375
# Train Epoch: 85 [38400/50000] Loss: 1.371193 Acc: 0.5469
# Elapsed 1553.23s, 18.06 s/epoch, 0.05 s/batch, ets 6574.12s
#
# Test set: Average loss: 1.3842, Accuracy: 4993/10000 (50%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 86 [12800/50000] Loss: 1.496375 Acc: 0.3594
# Train Epoch: 86 [25600/50000] Loss: 1.490000 Acc: 0.4141
# Train Epoch: 86 [38400/50000] Loss: 1.457018 Acc: 0.4609
# Elapsed 1570.91s, 18.06 s/epoch, 0.05 s/batch, ets 6554.50s
#
# Test set: Average loss: 1.3789, Accuracy: 5026/10000 (50%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 87 [12800/50000] Loss: 1.614563 Acc: 0.3516
# Train Epoch: 87 [25600/50000] Loss: 1.372242 Acc: 0.5000
# Train Epoch: 87 [38400/50000] Loss: 1.430542 Acc: 0.5078
# Elapsed 1588.38s, 18.05 s/epoch, 0.05 s/batch, ets 6534.01s
#
# Test set: Average loss: 1.3746, Accuracy: 5031/10000 (50%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 88 [12800/50000] Loss: 1.456922 Acc: 0.4453
# Train Epoch: 88 [25600/50000] Loss: 1.534930 Acc: 0.3984
# Train Epoch: 88 [38400/50000] Loss: 1.408558 Acc: 0.4766
# Elapsed 1607.07s, 18.06 s/epoch, 0.05 s/batch, ets 6518.58s
#
# Test set: Average loss: 1.3689, Accuracy: 5055/10000 (51%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 89 [12800/50000] Loss: 1.420646 Acc: 0.4453
# Train Epoch: 89 [25600/50000] Loss: 1.443238 Acc: 0.4375
# Train Epoch: 89 [38400/50000] Loss: 1.349249 Acc: 0.4922
# Elapsed 1625.62s, 18.06 s/epoch, 0.05 s/batch, ets 6502.47s
#
# Test set: Average loss: 1.3652, Accuracy: 5071/10000 (51%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 90 [12800/50000] Loss: 1.505418 Acc: 0.4297
# Train Epoch: 90 [25600/50000] Loss: 1.377076 Acc: 0.4688
# Train Epoch: 90 [38400/50000] Loss: 1.331031 Acc: 0.4453
# Elapsed 1644.39s, 18.07 s/epoch, 0.05 s/batch, ets 6487.20s
#
# Test set: Average loss: 1.3597, Accuracy: 5102/10000 (51%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 91 [12800/50000] Loss: 1.386930 Acc: 0.4766
# Train Epoch: 91 [25600/50000] Loss: 1.465346 Acc: 0.4609
# Train Epoch: 91 [38400/50000] Loss: 1.549631 Acc: 0.4297
# Elapsed 1662.49s, 18.07 s/epoch, 0.05 s/batch, ets 6469.26s
#
# Test set: Average loss: 1.3544, Accuracy: 5092/10000 (51%)
#
# Train Epoch: 92 [12800/50000] Loss: 1.404474 Acc: 0.4531
# Train Epoch: 92 [25600/50000] Loss: 1.513649 Acc: 0.5000
# Train Epoch: 92 [38400/50000] Loss: 1.379485 Acc: 0.5156
# Elapsed 1680.66s, 18.07 s/epoch, 0.05 s/batch, ets 6451.58s
#
# Test set: Average loss: 1.3490, Accuracy: 5127/10000 (51%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 93 [12800/50000] Loss: 1.475432 Acc: 0.4453
# Train Epoch: 93 [25600/50000] Loss: 1.351663 Acc: 0.5312
# Train Epoch: 93 [38400/50000] Loss: 1.447909 Acc: 0.4531
# Elapsed 1698.79s, 18.07 s/epoch, 0.05 s/batch, ets 6433.72s
#
# Test set: Average loss: 1.3456, Accuracy: 5146/10000 (51%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 94 [12800/50000] Loss: 1.462810 Acc: 0.4297
# Train Epoch: 94 [25600/50000] Loss: 1.379894 Acc: 0.4922
# Train Epoch: 94 [38400/50000] Loss: 1.435444 Acc: 0.4766
# Elapsed 1716.53s, 18.07 s/epoch, 0.05 s/batch, ets 6414.41s
#
# Test set: Average loss: 1.3412, Accuracy: 5152/10000 (52%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 95 [12800/50000] Loss: 1.470233 Acc: 0.4688
# Train Epoch: 95 [25600/50000] Loss: 1.236856 Acc: 0.5625
# Train Epoch: 95 [38400/50000] Loss: 1.356976 Acc: 0.4609
# Elapsed 1736.06s, 18.08 s/epoch, 0.05 s/batch, ets 6401.70s
#
# Test set: Average loss: 1.3363, Accuracy: 5176/10000 (52%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 96 [12800/50000] Loss: 1.481723 Acc: 0.4688
# Train Epoch: 96 [25600/50000] Loss: 1.403991 Acc: 0.5000
# Train Epoch: 96 [38400/50000] Loss: 1.334735 Acc: 0.4688
# Elapsed 1754.01s, 18.08 s/epoch, 0.05 s/batch, ets 6383.13s
#
# Test set: Average loss: 1.3310, Accuracy: 5205/10000 (52%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 97 [12800/50000] Loss: 1.341633 Acc: 0.5078
# Train Epoch: 97 [25600/50000] Loss: 1.356469 Acc: 0.4922
# Train Epoch: 97 [38400/50000] Loss: 1.299751 Acc: 0.5547
# Elapsed 1772.33s, 18.08 s/epoch, 0.05 s/batch, ets 6365.91s
#
# Test set: Average loss: 1.3277, Accuracy: 5223/10000 (52%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 98 [12800/50000] Loss: 1.366800 Acc: 0.5391
# Train Epoch: 98 [25600/50000] Loss: 1.479781 Acc: 0.4766
# Train Epoch: 98 [38400/50000] Loss: 1.386798 Acc: 0.4609
# Elapsed 1790.57s, 18.09 s/epoch, 0.05 s/batch, ets 6348.39s
#
# Test set: Average loss: 1.3210, Accuracy: 5213/10000 (52%)
#
# Train Epoch: 99 [12800/50000] Loss: 1.520709 Acc: 0.4062
# Train Epoch: 99 [25600/50000] Loss: 1.317931 Acc: 0.5547
# Train Epoch: 99 [38400/50000] Loss: 1.507603 Acc: 0.3828
# Elapsed 1808.45s, 18.08 s/epoch, 0.05 s/batch, ets 6329.59s
#
# Test set: Average loss: 1.3182, Accuracy: 5234/10000 (52%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 100 [12800/50000] Loss: 1.435676 Acc: 0.4062
# Train Epoch: 100 [25600/50000] Loss: 1.410024 Acc: 0.4688
# Train Epoch: 100 [38400/50000] Loss: 1.352105 Acc: 0.5469
# Elapsed 1827.21s, 18.09 s/epoch, 0.05 s/batch, ets 6313.83s
#
# Test set: Average loss: 1.3153, Accuracy: 5254/10000 (53%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 101 [12800/50000] Loss: 1.433698 Acc: 0.4844
# Train Epoch: 101 [25600/50000] Loss: 1.449971 Acc: 0.4766
# Train Epoch: 101 [38400/50000] Loss: 1.406670 Acc: 0.5156
# Elapsed 1845.19s, 18.09 s/epoch, 0.05 s/batch, ets 6295.35s
#
# Test set: Average loss: 1.3099, Accuracy: 5256/10000 (53%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 102 [12800/50000] Loss: 1.410152 Acc: 0.4219
# Train Epoch: 102 [25600/50000] Loss: 1.319234 Acc: 0.5469
# Train Epoch: 102 [38400/50000] Loss: 1.516822 Acc: 0.4453
# Elapsed 1863.72s, 18.09 s/epoch, 0.05 s/batch, ets 6278.75s
#
# Test set: Average loss: 1.3037, Accuracy: 5295/10000 (53%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 103 [12800/50000] Loss: 1.377698 Acc: 0.5156
# Train Epoch: 103 [25600/50000] Loss: 1.441569 Acc: 0.4844
# Train Epoch: 103 [38400/50000] Loss: 1.276548 Acc: 0.5469
# Elapsed 1881.32s, 18.09 s/epoch, 0.05 s/batch, ets 6259.00s
#
# Test set: Average loss: 1.3004, Accuracy: 5274/10000 (53%)
#
# Train Epoch: 104 [12800/50000] Loss: 1.356134 Acc: 0.4688
# Train Epoch: 104 [25600/50000] Loss: 1.484682 Acc: 0.4766
# Train Epoch: 104 [38400/50000] Loss: 1.556337 Acc: 0.4453
# Elapsed 1899.26s, 18.09 s/epoch, 0.05 s/batch, ets 6240.42s
#
# Test set: Average loss: 1.2958, Accuracy: 5319/10000 (53%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 105 [12800/50000] Loss: 1.390475 Acc: 0.4688
# Train Epoch: 105 [25600/50000] Loss: 1.470043 Acc: 0.5000
# Train Epoch: 105 [38400/50000] Loss: 1.387278 Acc: 0.4766
# Elapsed 1918.05s, 18.09 s/epoch, 0.05 s/batch, ets 6224.60s
#
# Test set: Average loss: 1.2925, Accuracy: 5342/10000 (53%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 106 [12800/50000] Loss: 1.362912 Acc: 0.5703
# Train Epoch: 106 [25600/50000] Loss: 1.364394 Acc: 0.5078
# Train Epoch: 106 [38400/50000] Loss: 1.380321 Acc: 0.4531
# Elapsed 1936.12s, 18.09 s/epoch, 0.05 s/batch, ets 6206.44s
#
# Test set: Average loss: 1.2874, Accuracy: 5344/10000 (53%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 107 [12800/50000] Loss: 1.399468 Acc: 0.4609
# Train Epoch: 107 [25600/50000] Loss: 1.279937 Acc: 0.5469
# Train Epoch: 107 [38400/50000] Loss: 1.352569 Acc: 0.5078
# Elapsed 1954.79s, 18.10 s/epoch, 0.05 s/batch, ets 6190.18s
#
# Test set: Average loss: 1.2835, Accuracy: 5373/10000 (54%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 108 [12800/50000] Loss: 1.276632 Acc: 0.4844
# Train Epoch: 108 [25600/50000] Loss: 1.449463 Acc: 0.4609
# Train Epoch: 108 [38400/50000] Loss: 1.312878 Acc: 0.5156
# Elapsed 1972.59s, 18.10 s/epoch, 0.05 s/batch, ets 6171.13s
#
# Test set: Average loss: 1.2797, Accuracy: 5363/10000 (54%)
#
# Train Epoch: 109 [12800/50000] Loss: 1.429956 Acc: 0.4297
# Train Epoch: 109 [25600/50000] Loss: 1.376762 Acc: 0.5078
# Train Epoch: 109 [38400/50000] Loss: 1.437364 Acc: 0.4453
# Elapsed 1991.98s, 18.11 s/epoch, 0.05 s/batch, ets 6157.03s
#
# Test set: Average loss: 1.2757, Accuracy: 5389/10000 (54%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 110 [12800/50000] Loss: 1.346037 Acc: 0.4844
# Train Epoch: 110 [25600/50000] Loss: 1.402122 Acc: 0.5078
# Train Epoch: 110 [38400/50000] Loss: 1.248983 Acc: 0.5391
# Elapsed 2009.47s, 18.10 s/epoch, 0.05 s/batch, ets 6137.02s
#
# Test set: Average loss: 1.2724, Accuracy: 5406/10000 (54%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 111 [12800/50000] Loss: 1.286570 Acc: 0.5234
# Train Epoch: 111 [25600/50000] Loss: 1.397046 Acc: 0.4922
# Train Epoch: 111 [38400/50000] Loss: 1.344778 Acc: 0.4453
# Elapsed 2027.41s, 18.10 s/epoch, 0.05 s/batch, ets 6118.44s
#
# Test set: Average loss: 1.2679, Accuracy: 5421/10000 (54%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 112 [12800/50000] Loss: 1.353150 Acc: 0.5000
# Train Epoch: 112 [25600/50000] Loss: 1.294699 Acc: 0.5234
# Train Epoch: 112 [38400/50000] Loss: 1.443009 Acc: 0.4766
# Elapsed 2045.96s, 18.11 s/epoch, 0.05 s/batch, ets 6101.67s
#
# Test set: Average loss: 1.2623, Accuracy: 5437/10000 (54%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 113 [12800/50000] Loss: 1.398128 Acc: 0.4922
# Train Epoch: 113 [25600/50000] Loss: 1.327285 Acc: 0.4844
# Train Epoch: 113 [38400/50000] Loss: 1.338754 Acc: 0.4766
# Elapsed 2063.81s, 18.10 s/epoch, 0.05 s/batch, ets 6082.80s
#
# Test set: Average loss: 1.2586, Accuracy: 5458/10000 (55%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 114 [12800/50000] Loss: 1.264435 Acc: 0.5234
# Train Epoch: 114 [25600/50000] Loss: 1.277353 Acc: 0.5938
# Train Epoch: 114 [38400/50000] Loss: 1.478570 Acc: 0.4609
# Elapsed 2082.19s, 18.11 s/epoch, 0.05 s/batch, ets 6065.52s
#
# Test set: Average loss: 1.2551, Accuracy: 5466/10000 (55%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 115 [12800/50000] Loss: 1.230191 Acc: 0.5547
# Train Epoch: 115 [25600/50000] Loss: 1.302595 Acc: 0.5078
# Train Epoch: 115 [38400/50000] Loss: 1.434474 Acc: 0.4688
# Elapsed 2099.79s, 18.10 s/epoch, 0.05 s/batch, ets 6045.96s
#
# Test set: Average loss: 1.2515, Accuracy: 5472/10000 (55%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 116 [12800/50000] Loss: 1.342654 Acc: 0.5078
# Train Epoch: 116 [25600/50000] Loss: 1.290818 Acc: 0.5703
# Train Epoch: 116 [38400/50000] Loss: 1.345026 Acc: 0.4688
# Elapsed 2117.53s, 18.10 s/epoch, 0.05 s/batch, ets 6026.83s
#
# Test set: Average loss: 1.2480, Accuracy: 5471/10000 (55%)
#
# Train Epoch: 117 [12800/50000] Loss: 1.279548 Acc: 0.5469
# Train Epoch: 117 [25600/50000] Loss: 1.213621 Acc: 0.6094
# Train Epoch: 117 [38400/50000] Loss: 1.368764 Acc: 0.4609
# Elapsed 2135.99s, 18.10 s/epoch, 0.05 s/batch, ets 6009.74s
#
# Test set: Average loss: 1.2429, Accuracy: 5490/10000 (55%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 118 [12800/50000] Loss: 1.390367 Acc: 0.4688
# Train Epoch: 118 [25600/50000] Loss: 1.279817 Acc: 0.4922
# Train Epoch: 118 [38400/50000] Loss: 1.321420 Acc: 0.4609
# Elapsed 2153.81s, 18.10 s/epoch, 0.05 s/batch, ets 5990.85s
#
# Test set: Average loss: 1.2394, Accuracy: 5518/10000 (55%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 119 [12800/50000] Loss: 1.485343 Acc: 0.4531
# Train Epoch: 119 [25600/50000] Loss: 1.359070 Acc: 0.5234
# Train Epoch: 119 [38400/50000] Loss: 1.322714 Acc: 0.5000
# Elapsed 2172.29s, 18.10 s/epoch, 0.05 s/batch, ets 5973.79s
#
# Test set: Average loss: 1.2358, Accuracy: 5537/10000 (55%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 120 [12800/50000] Loss: 1.388836 Acc: 0.5000
# Train Epoch: 120 [25600/50000] Loss: 1.498684 Acc: 0.4922
# Train Epoch: 120 [38400/50000] Loss: 1.287115 Acc: 0.5469
# Elapsed 2190.18s, 18.10 s/epoch, 0.05 s/batch, ets 5955.11s
#
# Test set: Average loss: 1.2316, Accuracy: 5543/10000 (55%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 121 [12800/50000] Loss: 1.284251 Acc: 0.5156
# Train Epoch: 121 [25600/50000] Loss: 1.328942 Acc: 0.4922
# Train Epoch: 121 [38400/50000] Loss: 1.343787 Acc: 0.4531
# Elapsed 2208.03s, 18.10 s/epoch, 0.05 s/batch, ets 5936.35s
#
# Test set: Average loss: 1.2276, Accuracy: 5573/10000 (56%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 122 [12800/50000] Loss: 1.160065 Acc: 0.5469
# Train Epoch: 122 [25600/50000] Loss: 1.181255 Acc: 0.5625
# Train Epoch: 122 [38400/50000] Loss: 1.221762 Acc: 0.5703
# Elapsed 2226.67s, 18.10 s/epoch, 0.05 s/batch, ets 5919.68s
#
# Test set: Average loss: 1.2248, Accuracy: 5576/10000 (56%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 123 [12800/50000] Loss: 1.228072 Acc: 0.5547
# Train Epoch: 123 [25600/50000] Loss: 1.299271 Acc: 0.5078
# Train Epoch: 123 [38400/50000] Loss: 1.231146 Acc: 0.4688
# Elapsed 2245.49s, 18.11 s/epoch, 0.05 s/batch, ets 5903.47s
#
# Test set: Average loss: 1.2208, Accuracy: 5579/10000 (56%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 124 [12800/50000] Loss: 1.261450 Acc: 0.5078
# Train Epoch: 124 [25600/50000] Loss: 1.503759 Acc: 0.4062
# Train Epoch: 124 [38400/50000] Loss: 1.324227 Acc: 0.5078
# Elapsed 2264.15s, 18.11 s/epoch, 0.05 s/batch, ets 5886.79s
#
# Test set: Average loss: 1.2154, Accuracy: 5612/10000 (56%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 125 [12800/50000] Loss: 1.445352 Acc: 0.4531
# Train Epoch: 125 [25600/50000] Loss: 1.234857 Acc: 0.5625
# Train Epoch: 125 [38400/50000] Loss: 1.313188 Acc: 0.5312
# Elapsed 2281.75s, 18.11 s/epoch, 0.05 s/batch, ets 5867.37s
#
# Test set: Average loss: 1.2120, Accuracy: 5632/10000 (56%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 126 [12800/50000] Loss: 1.365782 Acc: 0.4922
# Train Epoch: 126 [25600/50000] Loss: 1.416739 Acc: 0.4922
# Train Epoch: 126 [38400/50000] Loss: 1.246314 Acc: 0.5859
# Elapsed 2299.72s, 18.11 s/epoch, 0.05 s/batch, ets 5848.89s
#
# Test set: Average loss: 1.2093, Accuracy: 5636/10000 (56%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 127 [12800/50000] Loss: 1.280868 Acc: 0.4688
# Train Epoch: 127 [25600/50000] Loss: 1.239404 Acc: 0.5625
# Train Epoch: 127 [38400/50000] Loss: 1.301437 Acc: 0.4688
# Elapsed 2317.97s, 18.11 s/epoch, 0.05 s/batch, ets 5831.14s
#
# Test set: Average loss: 1.2062, Accuracy: 5661/10000 (57%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 128 [12800/50000] Loss: 1.361700 Acc: 0.5234
# Train Epoch: 128 [25600/50000] Loss: 1.326138 Acc: 0.4609
# Train Epoch: 128 [38400/50000] Loss: 1.271721 Acc: 0.5156
# Elapsed 2336.00s, 18.11 s/epoch, 0.05 s/batch, ets 5812.85s
#
# Test set: Average loss: 1.2016, Accuracy: 5686/10000 (57%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 129 [12800/50000] Loss: 1.243777 Acc: 0.5391
# Train Epoch: 129 [25600/50000] Loss: 1.235488 Acc: 0.5391
# Train Epoch: 129 [38400/50000] Loss: 1.367838 Acc: 0.5703
# Elapsed 2354.64s, 18.11 s/epoch, 0.05 s/batch, ets 5796.04s
#
# Test set: Average loss: 1.1972, Accuracy: 5682/10000 (57%)
#
# Train Epoch: 130 [12800/50000] Loss: 1.210845 Acc: 0.5703
# Train Epoch: 130 [25600/50000] Loss: 1.484324 Acc: 0.4531
# Train Epoch: 130 [38400/50000] Loss: 1.195446 Acc: 0.5625
# Elapsed 2372.72s, 18.11 s/epoch, 0.05 s/batch, ets 5777.85s
#
# Test set: Average loss: 1.1939, Accuracy: 5694/10000 (57%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 131 [12800/50000] Loss: 1.339610 Acc: 0.5234
# Train Epoch: 131 [25600/50000] Loss: 1.245071 Acc: 0.5469
# Train Epoch: 131 [38400/50000] Loss: 1.315777 Acc: 0.5156
# Elapsed 2391.08s, 18.11 s/epoch, 0.05 s/batch, ets 5760.32s
#
# Test set: Average loss: 1.1923, Accuracy: 5704/10000 (57%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 132 [12800/50000] Loss: 1.260745 Acc: 0.4688
# Train Epoch: 132 [25600/50000] Loss: 1.364133 Acc: 0.5312
# Train Epoch: 132 [38400/50000] Loss: 1.380737 Acc: 0.4922
# Elapsed 2409.39s, 18.12 s/epoch, 0.05 s/batch, ets 5742.69s
#
# Test set: Average loss: 1.1867, Accuracy: 5727/10000 (57%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 133 [12800/50000] Loss: 1.309855 Acc: 0.5078
# Train Epoch: 133 [25600/50000] Loss: 1.292086 Acc: 0.5547
# Train Epoch: 133 [38400/50000] Loss: 1.306188 Acc: 0.5234
# Elapsed 2427.61s, 18.12 s/epoch, 0.05 s/batch, ets 5724.81s
#
# Test set: Average loss: 1.1846, Accuracy: 5726/10000 (57%)
#
# Train Epoch: 134 [12800/50000] Loss: 1.389634 Acc: 0.4922
# Train Epoch: 134 [25600/50000] Loss: 1.441140 Acc: 0.4688
# Train Epoch: 134 [38400/50000] Loss: 1.354647 Acc: 0.5391
# Elapsed 2446.53s, 18.12 s/epoch, 0.05 s/batch, ets 5708.57s
#
# Test set: Average loss: 1.1822, Accuracy: 5742/10000 (57%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 135 [12800/50000] Loss: 1.147122 Acc: 0.6094
# Train Epoch: 135 [25600/50000] Loss: 1.307894 Acc: 0.5078
# Train Epoch: 135 [38400/50000] Loss: 1.234028 Acc: 0.5781
# Elapsed 2464.82s, 18.12 s/epoch, 0.05 s/batch, ets 5690.83s
#
# Test set: Average loss: 1.1799, Accuracy: 5753/10000 (58%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 136 [12800/50000] Loss: 1.343398 Acc: 0.4922
# Train Epoch: 136 [25600/50000] Loss: 1.232896 Acc: 0.5703
# Train Epoch: 136 [38400/50000] Loss: 1.209307 Acc: 0.5859
# Elapsed 2483.87s, 18.13 s/epoch, 0.05 s/batch, ets 5674.83s
#
# Test set: Average loss: 1.1732, Accuracy: 5773/10000 (58%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 137 [12800/50000] Loss: 1.287758 Acc: 0.5781
# Train Epoch: 137 [25600/50000] Loss: 1.293697 Acc: 0.5156
# Train Epoch: 137 [38400/50000] Loss: 1.284873 Acc: 0.5234
# Elapsed 2502.70s, 18.14 s/epoch, 0.05 s/batch, ets 5658.29s
#
# Test set: Average loss: 1.1690, Accuracy: 5821/10000 (58%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 138 [12800/50000] Loss: 1.333287 Acc: 0.5156
# Train Epoch: 138 [25600/50000] Loss: 1.371635 Acc: 0.4844
# Train Epoch: 138 [38400/50000] Loss: 1.155777 Acc: 0.6016
# Elapsed 2521.42s, 18.14 s/epoch, 0.05 s/batch, ets 5641.45s
#
# Test set: Average loss: 1.1689, Accuracy: 5792/10000 (58%)
#
# Train Epoch: 139 [12800/50000] Loss: 1.364249 Acc: 0.5625
# Train Epoch: 139 [25600/50000] Loss: 1.235396 Acc: 0.5312
# Train Epoch: 139 [38400/50000] Loss: 1.295784 Acc: 0.5234
# Elapsed 2539.06s, 18.14 s/epoch, 0.05 s/batch, ets 5622.20s
#
# Test set: Average loss: 1.1628, Accuracy: 5806/10000 (58%)
#
# Train Epoch: 140 [12800/50000] Loss: 1.333755 Acc: 0.4922
# Train Epoch: 140 [25600/50000] Loss: 1.270690 Acc: 0.4766
# Train Epoch: 140 [38400/50000] Loss: 1.333578 Acc: 0.5156
# Elapsed 2556.94s, 18.13 s/epoch, 0.05 s/batch, ets 5603.50s
#
# Test set: Average loss: 1.1589, Accuracy: 5853/10000 (59%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 141 [12800/50000] Loss: 1.176939 Acc: 0.5938
# Train Epoch: 141 [25600/50000] Loss: 1.182247 Acc: 0.5391
# Train Epoch: 141 [38400/50000] Loss: 1.509307 Acc: 0.4531
# Elapsed 2576.03s, 18.14 s/epoch, 0.05 s/batch, ets 5587.45s
#
# Test set: Average loss: 1.1560, Accuracy: 5842/10000 (58%)
#
# Train Epoch: 142 [12800/50000] Loss: 1.158690 Acc: 0.5781
# Train Epoch: 142 [25600/50000] Loss: 1.127421 Acc: 0.6094
# Train Epoch: 142 [38400/50000] Loss: 1.166939 Acc: 0.6094
# Elapsed 2593.72s, 18.14 s/epoch, 0.05 s/batch, ets 5568.33s
#
# Test set: Average loss: 1.1532, Accuracy: 5860/10000 (59%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 143 [12800/50000] Loss: 1.375183 Acc: 0.5156
# Train Epoch: 143 [25600/50000] Loss: 1.299611 Acc: 0.5391
# Train Epoch: 143 [38400/50000] Loss: 1.254119 Acc: 0.5859
# Elapsed 2612.17s, 18.14 s/epoch, 0.05 s/batch, ets 5550.87s
#
# Test set: Average loss: 1.1479, Accuracy: 5890/10000 (59%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 144 [12800/50000] Loss: 1.122627 Acc: 0.5781
# Train Epoch: 144 [25600/50000] Loss: 1.314825 Acc: 0.4922
# ...
#
# Test set: Average loss: 0.7449, Accuracy: 7391/10000 (74%)
#
# Train Epoch: 397 [12800/50000] Loss: 0.590308 Acc: 0.7969
# Train Epoch: 397 [25600/50000] Loss: 0.553213 Acc: 0.8281
# Train Epoch: 397 [38400/50000] Loss: 0.729043 Acc: 0.8047
# Elapsed 7284.66s, 18.30 s/epoch, 0.05 s/batch, ets 951.76s
#
# Test set: Average loss: 0.7442, Accuracy: 7382/10000 (74%)
#
# Train Epoch: 398 [12800/50000] Loss: 0.637325 Acc: 0.8047
# Train Epoch: 398 [25600/50000] Loss: 0.625090 Acc: 0.7656
# Train Epoch: 398 [38400/50000] Loss: 0.757465 Acc: 0.7656
# Elapsed 7303.77s, 18.31 s/epoch, 0.05 s/batch, ets 933.56s
#
# Test set: Average loss: 0.7515, Accuracy: 7358/10000 (74%)
#
# Train Epoch: 399 [12800/50000] Loss: 0.674525 Acc: 0.7500
# Train Epoch: 399 [25600/50000] Loss: 0.753515 Acc: 0.7422
# Train Epoch: 399 [38400/50000] Loss: 0.705590 Acc: 0.7812
# Elapsed 7321.60s, 18.30 s/epoch, 0.05 s/batch, ets 915.20s
#
# Test set: Average loss: 0.7428, Accuracy: 7421/10000 (74%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 400 [12800/50000] Loss: 0.655694 Acc: 0.7734
# Train Epoch: 400 [25600/50000] Loss: 0.552350 Acc: 0.8359
# Train Epoch: 400 [38400/50000] Loss: 0.737316 Acc: 0.7578
# Elapsed 7340.80s, 18.31 s/epoch, 0.05 s/batch, ets 897.01s
#
# Test set: Average loss: 0.7423, Accuracy: 7413/10000 (74%)
#
# Train Epoch: 401 [12800/50000] Loss: 0.495687 Acc: 0.8359
# Train Epoch: 401 [25600/50000] Loss: 0.713732 Acc: 0.7656
# Train Epoch: 401 [38400/50000] Loss: 0.604984 Acc: 0.8125
# Elapsed 7358.75s, 18.31 s/epoch, 0.05 s/batch, ets 878.66s
#
# Test set: Average loss: 0.7449, Accuracy: 7369/10000 (74%)
#
# Train Epoch: 402 [12800/50000] Loss: 0.632875 Acc: 0.8281
# Train Epoch: 402 [25600/50000] Loss: 0.522427 Acc: 0.8438
# Train Epoch: 402 [38400/50000] Loss: 0.564905 Acc: 0.7891
# Elapsed 7377.22s, 18.31 s/epoch, 0.05 s/batch, ets 860.37s
#
# Test set: Average loss: 0.7424, Accuracy: 7410/10000 (74%)
#
# Train Epoch: 403 [12800/50000] Loss: 0.648668 Acc: 0.7891
# Train Epoch: 403 [25600/50000] Loss: 0.592316 Acc: 0.7891
# Train Epoch: 403 [38400/50000] Loss: 0.480052 Acc: 0.8281
# Elapsed 7395.45s, 18.31 s/epoch, 0.05 s/batch, ets 842.06s
#
# Test set: Average loss: 0.7425, Accuracy: 7413/10000 (74%)
#
# Train Epoch: 404 [12800/50000] Loss: 0.737291 Acc: 0.6953
# Train Epoch: 404 [25600/50000] Loss: 0.597041 Acc: 0.8047
# Train Epoch: 404 [38400/50000] Loss: 0.693875 Acc: 0.7656
# Elapsed 7413.35s, 18.30 s/epoch, 0.05 s/batch, ets 823.71s
#
# Test set: Average loss: 0.7379, Accuracy: 7433/10000 (74%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 405 [12800/50000] Loss: 0.486496 Acc: 0.8594
# Train Epoch: 405 [25600/50000] Loss: 0.644919 Acc: 0.7578
# Train Epoch: 405 [38400/50000] Loss: 0.694377 Acc: 0.7734
# Elapsed 7432.48s, 18.31 s/epoch, 0.05 s/batch, ets 805.49s
#
# Test set: Average loss: 0.7447, Accuracy: 7381/10000 (74%)
#
# Train Epoch: 406 [12800/50000] Loss: 0.574144 Acc: 0.8125
# Train Epoch: 406 [25600/50000] Loss: 0.747847 Acc: 0.6953
# Train Epoch: 406 [38400/50000] Loss: 0.613679 Acc: 0.7656
# Elapsed 7450.51s, 18.31 s/epoch, 0.05 s/batch, ets 787.15s
#
# Test set: Average loss: 0.7447, Accuracy: 7390/10000 (74%)
#
# Train Epoch: 407 [12800/50000] Loss: 0.817290 Acc: 0.7266
# Train Epoch: 407 [25600/50000] Loss: 0.602217 Acc: 0.8125
# Train Epoch: 407 [38400/50000] Loss: 0.627147 Acc: 0.7734
# Elapsed 7469.36s, 18.31 s/epoch, 0.05 s/batch, ets 768.91s
#
# Test set: Average loss: 0.7422, Accuracy: 7396/10000 (74%)
#
# Train Epoch: 408 [12800/50000] Loss: 0.792299 Acc: 0.7266
# Train Epoch: 408 [25600/50000] Loss: 0.553501 Acc: 0.7656
# Train Epoch: 408 [38400/50000] Loss: 0.574428 Acc: 0.8125
# Elapsed 7487.50s, 18.31 s/epoch, 0.05 s/batch, ets 750.58s
#
# Test set: Average loss: 0.7387, Accuracy: 7437/10000 (74%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 409 [12800/50000] Loss: 0.806552 Acc: 0.6953
# Train Epoch: 409 [25600/50000] Loss: 0.682243 Acc: 0.7500
# Train Epoch: 409 [38400/50000] Loss: 0.553934 Acc: 0.8125
# Elapsed 7506.06s, 18.31 s/epoch, 0.05 s/batch, ets 732.30s
#
# Test set: Average loss: 0.7437, Accuracy: 7413/10000 (74%)
#
# Train Epoch: 410 [12800/50000] Loss: 0.546992 Acc: 0.8359
# Train Epoch: 410 [25600/50000] Loss: 0.703325 Acc: 0.7656
# Train Epoch: 410 [38400/50000] Loss: 0.645760 Acc: 0.7812
# Elapsed 7524.66s, 18.31 s/epoch, 0.05 s/batch, ets 714.02s
#
# Test set: Average loss: 0.7409, Accuracy: 7421/10000 (74%)
#
# Train Epoch: 411 [12800/50000] Loss: 0.660354 Acc: 0.7656
# Train Epoch: 411 [25600/50000] Loss: 0.628708 Acc: 0.7969
# Train Epoch: 411 [38400/50000] Loss: 0.566251 Acc: 0.8125
# Elapsed 7542.72s, 18.31 s/epoch, 0.05 s/batch, ets 695.69s
#
# Test set: Average loss: 0.7393, Accuracy: 7408/10000 (74%)
#
# Train Epoch: 412 [12800/50000] Loss: 0.595647 Acc: 0.8125
# Train Epoch: 412 [25600/50000] Loss: 0.792945 Acc: 0.7188
# Train Epoch: 412 [38400/50000] Loss: 0.594756 Acc: 0.7969
# Elapsed 7561.72s, 18.31 s/epoch, 0.05 s/batch, ets 677.44s
#
# Test set: Average loss: 0.7384, Accuracy: 7445/10000 (74%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 413 [12800/50000] Loss: 0.558578 Acc: 0.8281
# Train Epoch: 413 [25600/50000] Loss: 0.466936 Acc: 0.8438
# Train Epoch: 413 [38400/50000] Loss: 0.646957 Acc: 0.8047
# Elapsed 7579.77s, 18.31 s/epoch, 0.05 s/batch, ets 659.11s
#
# Test set: Average loss: 0.7378, Accuracy: 7416/10000 (74%)
#
# Train Epoch: 414 [12800/50000] Loss: 0.622150 Acc: 0.7812
# Train Epoch: 414 [25600/50000] Loss: 0.638829 Acc: 0.8281
# Train Epoch: 414 [38400/50000] Loss: 0.675190 Acc: 0.7734
# Elapsed 7598.40s, 18.31 s/epoch, 0.05 s/batch, ets 640.83s
#
# Test set: Average loss: 0.7432, Accuracy: 7394/10000 (74%)
#
# Train Epoch: 415 [12800/50000] Loss: 0.582709 Acc: 0.7734
# Train Epoch: 415 [25600/50000] Loss: 0.553694 Acc: 0.8203
# Train Epoch: 415 [38400/50000] Loss: 0.644913 Acc: 0.7578
# Elapsed 7616.33s, 18.31 s/epoch, 0.05 s/batch, ets 622.49s
#
# Test set: Average loss: 0.7342, Accuracy: 7440/10000 (74%)
#
# Train Epoch: 416 [12800/50000] Loss: 0.632907 Acc: 0.7734
# Train Epoch: 416 [25600/50000] Loss: 0.550723 Acc: 0.7891
# Train Epoch: 416 [38400/50000] Loss: 0.671494 Acc: 0.7344
# Elapsed 7634.62s, 18.31 s/epoch, 0.05 s/batch, ets 604.18s
#
# Test set: Average loss: 0.7396, Accuracy: 7398/10000 (74%)
#
# Train Epoch: 417 [12800/50000] Loss: 0.575248 Acc: 0.8203
# Train Epoch: 417 [25600/50000] Loss: 0.608065 Acc: 0.7578
# Train Epoch: 417 [38400/50000] Loss: 0.501899 Acc: 0.8125
# Elapsed 7652.96s, 18.31 s/epoch, 0.05 s/batch, ets 585.87s
#
# Test set: Average loss: 0.7327, Accuracy: 7448/10000 (74%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 418 [12800/50000] Loss: 0.614056 Acc: 0.7578
# Train Epoch: 418 [25600/50000] Loss: 0.711694 Acc: 0.7422
# Train Epoch: 418 [38400/50000] Loss: 0.659958 Acc: 0.7656
# Elapsed 7671.06s, 18.31 s/epoch, 0.05 s/batch, ets 567.55s
#
# Test set: Average loss: 0.7407, Accuracy: 7424/10000 (74%)
#
# Train Epoch: 419 [12800/50000] Loss: 0.552202 Acc: 0.8125
# Train Epoch: 419 [25600/50000] Loss: 0.687747 Acc: 0.7812
# Train Epoch: 419 [38400/50000] Loss: 0.498239 Acc: 0.8203
# Elapsed 7689.86s, 18.31 s/epoch, 0.05 s/batch, ets 549.28s
#
# Test set: Average loss: 0.7398, Accuracy: 7419/10000 (74%)
#
# Train Epoch: 420 [12800/50000] Loss: 0.710926 Acc: 0.7109
# Train Epoch: 420 [25600/50000] Loss: 0.596109 Acc: 0.7969
# Train Epoch: 420 [38400/50000] Loss: 0.445667 Acc: 0.8594
# Elapsed 7707.87s, 18.31 s/epoch, 0.05 s/batch, ets 530.95s
#
# Test set: Average loss: 0.7380, Accuracy: 7433/10000 (74%)
#
# Train Epoch: 421 [12800/50000] Loss: 0.546862 Acc: 0.7656
# Train Epoch: 421 [25600/50000] Loss: 0.568201 Acc: 0.8203
# Train Epoch: 421 [38400/50000] Loss: 0.659297 Acc: 0.7812
# Elapsed 7726.61s, 18.31 s/epoch, 0.05 s/batch, ets 512.67s
#
# Test set: Average loss: 0.7343, Accuracy: 7421/10000 (74%)
#
# Train Epoch: 422 [12800/50000] Loss: 0.588966 Acc: 0.8203
# Train Epoch: 422 [25600/50000] Loss: 0.611479 Acc: 0.7734
# Train Epoch: 422 [38400/50000] Loss: 0.584820 Acc: 0.8281
# Elapsed 7744.68s, 18.31 s/epoch, 0.05 s/batch, ets 494.34s
#
# Test set: Average loss: 0.7365, Accuracy: 7424/10000 (74%)
#
# Train Epoch: 423 [12800/50000] Loss: 0.552355 Acc: 0.7812
# Train Epoch: 423 [25600/50000] Loss: 0.603140 Acc: 0.7578
# Train Epoch: 423 [38400/50000] Loss: 0.633326 Acc: 0.7734
# Elapsed 7762.88s, 18.31 s/epoch, 0.05 s/batch, ets 476.03s
#
# Test set: Average loss: 0.7468, Accuracy: 7413/10000 (74%)
#
# Train Epoch: 424 [12800/50000] Loss: 0.501637 Acc: 0.8125
# Train Epoch: 424 [25600/50000] Loss: 0.727334 Acc: 0.7031
# Train Epoch: 424 [38400/50000] Loss: 0.540181 Acc: 0.8125
# Elapsed 7781.49s, 18.31 s/epoch, 0.05 s/batch, ets 457.73s
#
# Test set: Average loss: 0.7391, Accuracy: 7422/10000 (74%)
#
# Train Epoch: 425 [12800/50000] Loss: 0.492827 Acc: 0.8359
# Train Epoch: 425 [25600/50000] Loss: 0.599190 Acc: 0.8125
# Train Epoch: 425 [38400/50000] Loss: 0.631593 Acc: 0.7344
# Elapsed 7799.45s, 18.31 s/epoch, 0.05 s/batch, ets 439.41s
#
# Test set: Average loss: 0.7338, Accuracy: 7437/10000 (74%)
#
# Train Epoch: 426 [12800/50000] Loss: 0.624332 Acc: 0.7969
# Train Epoch: 426 [25600/50000] Loss: 0.551620 Acc: 0.8359
# Train Epoch: 426 [38400/50000] Loss: 0.594974 Acc: 0.8359
# Elapsed 7818.22s, 18.31 s/epoch, 0.05 s/batch, ets 421.12s
#
# Test set: Average loss: 0.7380, Accuracy: 7419/10000 (74%)
#
# Train Epoch: 427 [12800/50000] Loss: 0.555748 Acc: 0.8125
# Train Epoch: 427 [25600/50000] Loss: 0.594362 Acc: 0.8125
# Train Epoch: 427 [38400/50000] Loss: 0.475862 Acc: 0.8672
# Elapsed 7836.08s, 18.31 s/epoch, 0.05 s/batch, ets 402.79s
#
# Test set: Average loss: 0.7361, Accuracy: 7396/10000 (74%)
#
# Train Epoch: 428 [12800/50000] Loss: 0.658025 Acc: 0.7656
# Train Epoch: 428 [25600/50000] Loss: 0.640096 Acc: 0.7891
# Train Epoch: 428 [38400/50000] Loss: 0.507878 Acc: 0.8125
# Elapsed 7854.78s, 18.31 s/epoch, 0.05 s/batch, ets 384.50s
#
# Test set: Average loss: 0.7419, Accuracy: 7430/10000 (74%)
#
# Train Epoch: 429 [12800/50000] Loss: 0.662677 Acc: 0.7656
# Train Epoch: 429 [25600/50000] Loss: 0.550154 Acc: 0.8047
# Train Epoch: 429 [38400/50000] Loss: 0.680555 Acc: 0.7578
# Elapsed 7872.54s, 18.31 s/epoch, 0.05 s/batch, ets 366.16s
#
# Test set: Average loss: 0.7305, Accuracy: 7456/10000 (75%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 430 [12800/50000] Loss: 0.562612 Acc: 0.8203
# Train Epoch: 430 [25600/50000] Loss: 0.579515 Acc: 0.7969
# Train Epoch: 430 [38400/50000] Loss: 0.498434 Acc: 0.8438
# Elapsed 7890.77s, 18.31 s/epoch, 0.05 s/batch, ets 347.85s
#
# Test set: Average loss: 0.7347, Accuracy: 7429/10000 (74%)
#
# Train Epoch: 431 [12800/50000] Loss: 0.526118 Acc: 0.8125
# Train Epoch: 431 [25600/50000] Loss: 0.505023 Acc: 0.8281
# Train Epoch: 431 [38400/50000] Loss: 0.478084 Acc: 0.8281
# Elapsed 7909.14s, 18.31 s/epoch, 0.05 s/batch, ets 329.55s
#
# Test set: Average loss: 0.7309, Accuracy: 7451/10000 (75%)
#
# Train Epoch: 432 [12800/50000] Loss: 0.490043 Acc: 0.8359
# Train Epoch: 432 [25600/50000] Loss: 0.609903 Acc: 0.7891
# Train Epoch: 432 [38400/50000] Loss: 0.708419 Acc: 0.7734
# Elapsed 7927.20s, 18.31 s/epoch, 0.05 s/batch, ets 311.23s
#
# Test set: Average loss: 0.7343, Accuracy: 7432/10000 (74%)
#
# Train Epoch: 433 [12800/50000] Loss: 0.427528 Acc: 0.8672
# Train Epoch: 433 [25600/50000] Loss: 0.431946 Acc: 0.8359
# Train Epoch: 433 [38400/50000] Loss: 0.494998 Acc: 0.8594
# Elapsed 7946.17s, 18.31 s/epoch, 0.05 s/batch, ets 292.95s
#
# Test set: Average loss: 0.7329, Accuracy: 7451/10000 (75%)
#
# Train Epoch: 434 [12800/50000] Loss: 0.574480 Acc: 0.7812
# Train Epoch: 434 [25600/50000] Loss: 0.472272 Acc: 0.8672
# Train Epoch: 434 [38400/50000] Loss: 0.545523 Acc: 0.8047
# Elapsed 7963.97s, 18.31 s/epoch, 0.05 s/batch, ets 274.62s
#
# Test set: Average loss: 0.7347, Accuracy: 7450/10000 (74%)
#
# Train Epoch: 435 [12800/50000] Loss: 0.573904 Acc: 0.8203
# Train Epoch: 435 [25600/50000] Loss: 0.593323 Acc: 0.7266
# Train Epoch: 435 [38400/50000] Loss: 0.646505 Acc: 0.8047
# Elapsed 7982.92s, 18.31 s/epoch, 0.05 s/batch, ets 256.33s
#
# Test set: Average loss: 0.7446, Accuracy: 7397/10000 (74%)
#
# Train Epoch: 436 [12800/50000] Loss: 0.617337 Acc: 0.7734
# Train Epoch: 436 [25600/50000] Loss: 0.599235 Acc: 0.7734
# Train Epoch: 436 [38400/50000] Loss: 0.568610 Acc: 0.7891
# Elapsed 8001.10s, 18.31 s/epoch, 0.05 s/batch, ets 238.02s
#
# Test set: Average loss: 0.7316, Accuracy: 7453/10000 (75%)
#
# Train Epoch: 437 [12800/50000] Loss: 0.592243 Acc: 0.7812
# Train Epoch: 437 [25600/50000] Loss: 0.491026 Acc: 0.8516
# Train Epoch: 437 [38400/50000] Loss: 0.513594 Acc: 0.8516
# Elapsed 8019.49s, 18.31 s/epoch, 0.05 s/batch, ets 219.71s
#
# Test set: Average loss: 0.7344, Accuracy: 7453/10000 (75%)
#
# Train Epoch: 438 [12800/50000] Loss: 0.450300 Acc: 0.8281
# Train Epoch: 438 [25600/50000] Loss: 0.678437 Acc: 0.8047
# Train Epoch: 438 [38400/50000] Loss: 0.481480 Acc: 0.8438
# Elapsed 8038.83s, 18.31 s/epoch, 0.05 s/batch, ets 201.43s
#
# Test set: Average loss: 0.7313, Accuracy: 7443/10000 (74%)
#
# Train Epoch: 439 [12800/50000] Loss: 0.612142 Acc: 0.7969
# Train Epoch: 439 [25600/50000] Loss: 0.629796 Acc: 0.7969
# Train Epoch: 439 [38400/50000] Loss: 0.540105 Acc: 0.7578
# Elapsed 8057.26s, 18.31 s/epoch, 0.05 s/batch, ets 183.12s
#
# Test set: Average loss: 0.7324, Accuracy: 7447/10000 (74%)
#
# Train Epoch: 440 [12800/50000] Loss: 0.582885 Acc: 0.8203
# Train Epoch: 440 [25600/50000] Loss: 0.508972 Acc: 0.8281
# Train Epoch: 440 [38400/50000] Loss: 0.492062 Acc: 0.8359
# Elapsed 8077.01s, 18.32 s/epoch, 0.05 s/batch, ets 164.84s
#
# Test set: Average loss: 0.7318, Accuracy: 7467/10000 (75%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 441 [12800/50000] Loss: 0.568137 Acc: 0.7812
# Train Epoch: 441 [25600/50000] Loss: 0.467962 Acc: 0.8516
# Train Epoch: 441 [38400/50000] Loss: 0.390439 Acc: 0.9062
# Elapsed 8095.51s, 18.32 s/epoch, 0.05 s/batch, ets 146.53s
#
# Test set: Average loss: 0.7357, Accuracy: 7436/10000 (74%)
#
# Train Epoch: 442 [12800/50000] Loss: 0.574616 Acc: 0.7891
# Train Epoch: 442 [25600/50000] Loss: 0.564373 Acc: 0.7812
# Train Epoch: 442 [38400/50000] Loss: 0.479908 Acc: 0.8281
# Elapsed 8114.93s, 18.32 s/epoch, 0.05 s/batch, ets 128.23s
#
# Test set: Average loss: 0.7292, Accuracy: 7466/10000 (75%)
#
# Train Epoch: 443 [12800/50000] Loss: 0.442710 Acc: 0.8672
# Train Epoch: 443 [25600/50000] Loss: 0.536873 Acc: 0.7969
# Train Epoch: 443 [38400/50000] Loss: 0.531115 Acc: 0.8047
# Elapsed 8133.38s, 18.32 s/epoch, 0.05 s/batch, ets 109.91s
#
# Test set: Average loss: 0.7285, Accuracy: 7469/10000 (75%)
#
# Accuracy improved, saving the model.
#
# Train Epoch: 444 [12800/50000] Loss: 0.606947 Acc: 0.8047
# Train Epoch: 444 [25600/50000] Loss: 0.467949 Acc: 0.8125
# Train Epoch: 444 [38400/50000] Loss: 0.469925 Acc: 0.8203
# Elapsed 8152.31s, 18.32 s/epoch, 0.05 s/batch, ets 91.60s
#
# Test set: Average loss: 0.7334, Accuracy: 7461/10000 (75%)
#
# Train Epoch: 445 [12800/50000] Loss: 0.590437 Acc: 0.8047
# Train Epoch: 445 [25600/50000] Loss: 0.506887 Acc: 0.8281
# Train Epoch: 445 [38400/50000] Loss: 0.555904 Acc: 0.7969
# Elapsed 8170.69s, 18.32 s/epoch, 0.05 s/batch, ets 73.28s
#
# Test set: Average loss: 0.7368, Accuracy: 7464/10000 (75%)
#
# Train Epoch: 446 [12800/50000] Loss: 0.481961 Acc: 0.8516
# Train Epoch: 446 [25600/50000] Loss: 0.553362 Acc: 0.8203
# Train Epoch: 446 [38400/50000] Loss: 0.464312 Acc: 0.8594
# Elapsed 8189.36s, 18.32 s/epoch, 0.05 s/batch, ets 54.96s
#
# Test set: Average loss: 0.7335, Accuracy: 7458/10000 (75%)
#
# Train Epoch: 447 [12800/50000] Loss: 0.520325 Acc: 0.8359
# Train Epoch: 447 [25600/50000] Loss: 0.456950 Acc: 0.8594
# Train Epoch: 447 [38400/50000] Loss: 0.777485 Acc: 0.7500
# Elapsed 8207.56s, 18.32 s/epoch, 0.05 s/batch, ets 36.64s
#
# Test set: Average loss: 0.7294, Accuracy: 7461/10000 (75%)
#
# Train Epoch: 448 [12800/50000] Loss: 0.471286 Acc: 0.8281
# Train Epoch: 448 [25600/50000] Loss: 0.495034 Acc: 0.8281
# Train Epoch: 448 [38400/50000] Loss: 0.559568 Acc: 0.8125
# Elapsed 8225.76s, 18.32 s/epoch, 0.05 s/batch, ets 18.32s
#
# Test set: Average loss: 0.7414, Accuracy: 7446/10000 (74%)
#
# Train Epoch: 449 [12800/50000] Loss: 0.475175 Acc: 0.8516
# Train Epoch: 449 [25600/50000] Loss: 0.580554 Acc: 0.7969
# Train Epoch: 449 [38400/50000] Loss: 0.438680 Acc: 0.8281
# Elapsed 8245.06s, 18.32 s/epoch, 0.05 s/batch, ets 0.00s
#
# Test set: Average loss: 0.7274, Accuracy: 7469/10000 (75%)
#
# Total time: 8248.05, Best Loss: 0.727, Best Accuracy: 0.747

# %% [markdown]
# # <font style="color:blue">12. Plot Loss</font>

# %%
# Plot loss
plt.rcParams["figure.figsize"] = (10, 6)
x = range(len(epoch_train_loss))


plt.figure
plt.plot(x, epoch_train_loss, color='r', label="train loss")
plt.plot(x, epoch_test_loss, color='b', label="validation loss")
plt.xlabel('epoch no.')
plt.ylabel('loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # <font style="color:blue">13. Plot Accuracy</font>

# %%
# Plot loss
plt.rcParams["figure.figsize"] = (10, 6)
x = range(len(epoch_train_loss))


plt.figure
plt.plot(x, epoch_train_acc, color='r', label="train accuracy")
plt.plot(x, epoch_test_acc, color='b', label="validation accuracy")
plt.xlabel('epoch no.')
plt.ylabel('accuracy')
plt.legend(loc='center right')
plt.title('Training and Validation Accuracy')
plt.show()

# %% [markdown]
# # <font style="color:blue">14. Loading the Model </font>

# %%
# initialize the model
cnn_model = MyModel()

models = 'models'

model_file_name = 'cifar10_cnn_model.pt'

model_path = os.path.join(models, model_file_name)

# loading the model and getting model parameters by using load_state_dict
cnn_model.load_state_dict(torch.load(model_path))
# Out:
# <ipython-input-22-f09b9e31dab8>:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   cnn_model.load_state_dict(torch.load(model_path))
# <All keys matched successfully>

# %% [markdown]
# # <font style="color:blue">15. Model Prediction</font>

# %%
def prediction(model, train_config, batch_input):

    # send model to cpu/cuda according to your system configuration
    model.to(train_config.device)

    # it is important to do model.eval() before prediction
    model.eval()

    data = batch_input.to(train_config.device)

    output = model(data)

    # Score to probability using softmax
    prob = F.softmax(output, dim=1)

    # get the max probability
    pred_prob = prob.data.max(dim=1)[0]

    # get the index of the max probability
    pred_index = prob.data.max(dim=1)[1]

    return pred_index.cpu().numpy(), pred_prob.cpu().numpy()

# %% [markdown]
# # <font style="color:blue">16. Perform Inference on sample images </font>
#
# For prediction, we need to transform the data in the same way as we have done during training.

# %%
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

batch_size = 5
train_config = TrainingConfiguration()

if torch.cuda.is_available():
    train_config.device = "cuda"
else:
    train_config.device = "cpu"



# load test data without image transformation
test = torch.utils.data.DataLoader(
    datasets.CIFAR10(root=train_config.data_root, train=False, download=False,
                   transform=transforms.functional.to_tensor),
    batch_size=batch_size,
    shuffle=False,
    num_workers=1
    )

try:
    mean, std = get_mean_std_train_data(data_root)
    assert len(mean) == len(std) == 3
except:
    mean = (0.5, 0.5, 0.5)
    std = (0.5, 0.5, 0.5)

# load testdata with image transformation
image_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean, std)
    ])

test_trans = torch.utils.data.DataLoader(
    datasets.CIFAR10(root=train_config.data_root, train=False, download=False, transform=image_transforms),
    batch_size=batch_size,
    shuffle=False,
    num_workers=1
    )

for data, _ in test_trans:
    # pass the loaded model
    pred, prob = prediction(cnn_model, train_config, data)
    break


plt.rcParams["figure.figsize"] = (3, 3)
for images, label in test:
    for i, img in enumerate(images):
        img = transforms.functional.to_pil_image(img)
        plt.imshow(img)
        plt.gca().set_title('Pred: {0}({1:0.2}), Label: {2}'.format(classes[pred[i]], prob[i], classes[label[i]]))
        plt.show()
    break

# %% [markdown]
# # <font style="color:blue">17. Report your findings</font>
#
# - I experimented with several CNN architectures as well as learning rates and batch sizes
# - In the experiments the following issues were relevant:
#    - when using small values for batch size, the gap between loss curves for training and validation increased
#    - learning rates also showed different performance. The final learning rated used allowed a good trade-off between optimal accuracy and processing time
#    - shallow architectures did not allow to get an accuracy over the minimun threshold
#    - Deep architectures fell into overfitting early (around 17th epoch)
#    - To avoid overfitting in the fully connected part of the CNN two dropout layers were added
# - The best architecture was the one reported here

# %% [markdown]
# # <font style="color:blue">References</font>
#
# 1. https://pytorch.org/tutorials/beginner/data_loading_tutorial.html
# 1. https://pytorch.org/tutorials/beginner/saving_loading_models.html
